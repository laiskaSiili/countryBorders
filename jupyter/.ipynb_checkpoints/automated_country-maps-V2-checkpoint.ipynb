# %% [markdown]
# # Country maps prototype V2 - WIP

# %% [markdown]
# ### Summary
# The polygon geometries of all countries are clustered in a distance based manner by using a 2-pass algorithm. The resulting list of geometry group is then visualized in a ipyleaflet map, which allows to label the groups. The list is continuously saved as a pickle object, therefore saving any changes made to it.

# %% [markdown]
# #### Setup
# For dependency handling, create a new virtual environment from the requirements.txt, then add it as a jupyter kernel to use it in this notebook:
# 1. Assuming you have virtualenv wrapper, create a new virtual environment using *mkvirtualenv venv_name*.
# 2. Enter virtual environment using *workon venv_name*.
# 3. Install dependencies from requirements file using *pip install -r requirements.txt*.
# 4. Install jupyter kernel using *ipython kernel install --user --name=venv_name*.
# 5. Select newly installed kernel in jupyert notebook via *Kernel -> Change kernel*.
# 6. (optional) To uninstall the kernel later, use *jupyter kernelspec uninstall kernel_name*.

# %%
# Hidden depedency of geopandas: descartes
import geopandas as gpd
import matplotlib.pyplot as plt
import pickle
from ipyleaflet import *
import ipywidgets as widgets

# %% [markdown]
# ### Preprocess Datasets
# Datasets are from [naturalearthdata](https://www.naturalearthdata.com/downloads/10m-cultural-vectors/) with public license, meaning they are free to use for everybody. For countries the dataset **Admin 0 – Countries** is used.

# %%
all_countries_4326 = gpd.read_file('data/ne_50m_admin_0_countries/ne_50m_admin_0_countries.shp')

# %% [markdown]
# ### Algorithm
# The following algorithm groups performs a distance based clustering on the polygons of each country in order to facilitate plotting. A two pass approach is applied, whereby in the first pass all polygons within a smaller radius around the largest polygon are grouped together. In a second pass, all polygons within a larger radius around the resulting group of pass 1 are also merged together. All merged polygons from pass1 and pass2 are then removed and the process is repeated until no more polygons are left. The two pass approach aims at reducing artifacts that arise when a country consists of several large polygons in close distance and some smaller polygon groups further away (e.g. Japan).
# ### Ouput
# A list of dictionaries, of which each describes a single group generated by the algorithm. Each country therefore has 1 or several dictionary objects in the list belonging to it. Each dictionary contains the following:
# - The country name and ISO signature that this dictionary belongs to.
# - A polygon or multipolygon geometry.
# - A name that corresponds to the polygon group. It is here assumed that the group with the largest area is the country. All other groups are labelled "Unknown X" with X being a numbering.

# %% [markdown]
# ### Pseudo Algorithm
# 0. Read countries and project to EPSG 3857 (pseudomercator).
# 1. Iterate over all countries, and perform the following...
# 2. Split the country geometry into single polygons.
# 3. Pass 1: Find largest polygon, create a buffer around it and use the resulting bounding box to find all polygons that have their centroid within and merge all of them into a multipolygon.
# 4. Pass 2: Using the resulting geometry of step 3, create a larger buffer and again find all polygons with their centroid within the resulting bounding box and merge them.
# 5. Remove the resulting multipolygon from the two passes from the dataset and add it to a geometry list.
# 6. If there still are polygons left, go to step 3.
# 7. If the country consists of a single polygon, skip steps 3-6 and directly add it to the geometry list.
# 8. Convert the resulting geometries from the geometry list back to EPSG 4326 and add them to the result list.

# %%
country_list = []
min_x = -20037508.342789
max_x = 20037508.342789
dissolve_buffer_m = 500000
# 0. Read countries and project to EPSG 3857 (pseudomercator).
# Project layer to EPSG 3857, because shapely only supports buffer calculations on cartesian plane.
all_countries_3857 = all_countries_4326.to_crs(epsg=3857)
all_countries_3857['geometry'] = all_countries_3857#.translate(xoff=translation_offset)
# 1. Iterate over all countries, and perform the following...
for index, country in all_countries_3857.iterrows():
    geometry_groups = []
    geoseries = []
    if country.geometry.geom_type == 'Polygon':
        # Process single polygon
        nr_iterations_list = [1]
        geometry_groups.append(country.geometry)
    else:
        # Process multipolygon
        # 2. Split the country geometry into single polygons.
        
        country_parts = gpd.GeoDataFrame({'geometry': country.geometry}, crs=all_countries_3857.crs)
        nr_iterations = 0
        nr_iterations_list = []
        while country_parts.shape[0] > 0:
            sum_within_before = 0
            primary = country_parts[country_parts.area == country_parts.area.max()].unary_union
            while True:
                nr_iterations += 1
                primary_buffered_bbox = primary.buffer(distance=dissolve_buffer_m).envelope
                within_primary_bool = country_parts.centroid.within(primary_buffered_bbox)
                primary = country_parts.loc[within_primary_bool].unary_union
                sum_within = sum(within_primary_bool)
                if sum_within == sum_within_before:
                    nr_iterations_list.append(nr_iterations)
                    nr_iterations = 0
                    break
                sum_within_before = sum_within
            country_parts = country_parts.loc[within_primary_bool == False]
            geometry_groups.append(primary)
    print(f'Processed: {country["ADMIN"]} ({country["ISO_A3"]}), iterations: {",".join(str(x) for x in nr_iterations_list)}')

    # 8. Convert the resulting geometries from the geometry list back to EPSG 4326 and add them to the result list.
    # Create a list of country parts that allows easy navigation for subsequent name entering. Assume largest Polygon is has country name as title.
    #geometry_groups = [gpd.GeoSeries(geom, crs=3857).translate(xoff=-translation_offset).to_crs(epsg=4326).geometry for geom in geometry_groups]
    geometry_groups = [gpd.GeoSeries(geom, crs=3857).to_crs(epsg=4326).geometry for geom in geometry_groups]
    if len(geometry_groups) > 1:
        country_list.append({
            'country': country['ADMIN'],
            'ISO_A3': country['ISO_A3'],
            'name': country['ADMIN'],
            'geometry': geometry_groups.pop(0),
        })
        for i, geometry in enumerate(geometry_groups):
            country_list.append({
                'country': country['ADMIN'],
                'ISO_A3': country['ISO_A3'],
                'name': f'Unknown {i}',
                'geometry': geometry
            })
# Out:
# Processed: Zimbabwe (ZWE), iterations: 1
# Processed: Zambia (ZMB), iterations: 1
# Processed: Yemen (YEM), iterations: 2
# Processed: Vietnam (VNM), iterations: 2
# Processed: Venezuela (VEN), iterations: 2
# Processed: Vatican (VAT), iterations: 1
# Processed: Vanuatu (VUT), iterations: 3
# Processed: Uzbekistan (UZB), iterations: 2
# Processed: Uruguay (URY), iterations: 1
# Processed: Federated States of Micronesia (FSM), iterations: 2,2,2,2
# Processed: Marshall Islands (MHL), iterations: 2
# Processed: Northern Mariana Islands (MNP), iterations: 2
# Processed: United States Virgin Islands (VIR), iterations: 2
# Processed: Guam (GUM), iterations: 1
# Processed: American Samoa (ASM), iterations: 1
# Processed: Puerto Rico (PRI), iterations: 2
# Processed: United States of America (USA), iterations: 2,4,2,3
# Processed: South Georgia and the Islands (SGS), iterations: 2,2
# Processed: British Indian Ocean Territory (IOT), iterations: 1
# Processed: Saint Helena (SHN), iterations: 2,2
# Processed: Pitcairn Islands (PCN), iterations: 1
# Processed: Anguilla (AIA), iterations: 1
# Processed: Falkland Islands (FLK), iterations: 2
# Processed: Cayman Islands (CYM), iterations: 2
# Processed: Bermuda (BMU), iterations: 1
# Processed: British Virgin Islands (VGB), iterations: 2
# Processed: Turks and Caicos Islands (TCA), iterations: 2
# Processed: Montserrat (MSR), iterations: 1
# Processed: Jersey (JEY), iterations: 1
# Processed: Guernsey (GGY), iterations: 1
# Processed: Isle of Man (IMN), iterations: 1
# Processed: United Kingdom (GBR), iterations: 2
# Processed: United Arab Emirates (ARE), iterations: 2
# Processed: Ukraine (UKR), iterations: 2
# Processed: Uganda (UGA), iterations: 1
# Processed: Turkmenistan (TKM), iterations: 2
# Processed: Turkey (TUR), iterations: 2
# Processed: Tunisia (TUN), iterations: 2
# Processed: Trinidad and Tobago (TTO), iterations: 2
# Processed: Tonga (TON), iterations: 2
# Processed: Togo (TGO), iterations: 1
# Processed: East Timor (TLS), iterations: 2
# Processed: Thailand (THA), iterations: 2
# Processed: United Republic of Tanzania (TZA), iterations: 2
# Processed: Tajikistan (TJK), iterations: 2
# Processed: Taiwan (TWN), iterations: 2
# Processed: Syria (SYR), iterations: 1
# Processed: Switzerland (CHE), iterations: 1
# Processed: Sweden (SWE), iterations: 2
# Processed: eSwatini (SWZ), iterations: 1
# Processed: Suriname (SUR), iterations: 1
# Processed: South Sudan (SSD), iterations: 1
# Processed: Sudan (SDN), iterations: 1
# Processed: Sri Lanka (LKA), iterations: 2
# Processed: Spain (ESP), iterations: 2,2
# Processed: South Korea (KOR), iterations: 2
# Processed: South Africa (ZAF), iterations: 2,2
# Processed: Somalia (SOM), iterations: 1
# Processed: Somaliland (-99), iterations: 1
# Processed: Solomon Islands (SLB), iterations: 3
# Processed: Slovakia (SVK), iterations: 1
# Processed: Slovenia (SVN), iterations: 1
# Processed: Singapore (SGP), iterations: 1
# Processed: Sierra Leone (SLE), iterations: 2
# Processed: Seychelles (SYC), iterations: 1
# Processed: Republic of Serbia (SRB), iterations: 1
# Processed: Senegal (SEN), iterations: 1
# Processed: Saudi Arabia (SAU), iterations: 2
# Processed: São Tomé and Principe (STP), iterations: 2
# Processed: San Marino (SMR), iterations: 1
# Processed: Samoa (WSM), iterations: 2
# Processed: Saint Vincent and the Grenadines (VCT), iterations: 2
# Processed: Saint Lucia (LCA), iterations: 1
# Processed: Saint Kitts and Nevis (KNA), iterations: 2
# Processed: Rwanda (RWA), iterations: 1
# Processed: Russia (RUS), iterations: 6,2,2,2
# Processed: Romania (ROU), iterations: 1
# Processed: Qatar (QAT), iterations: 1
# Processed: Portugal (PRT), iterations: 2,3,2
# Processed: Poland (POL), iterations: 1
# Processed: Philippines (PHL), iterations: 3
# Processed: Peru (PER), iterations: 1
# Processed: Paraguay (PRY), iterations: 1
# Processed: Papua New Guinea (PNG), iterations: 2
# Processed: Panama (PAN), iterations: 2
# Processed: Palau (PLW), iterations: 2
# Processed: Pakistan (PAK), iterations: 1
# Processed: Oman (OMN), iterations: 2
# Processed: Norway (-99), iterations: 2,4,2,2
# Processed: North Korea (PRK), iterations: 2
# Processed: Nigeria (NGA), iterations: 2
# Processed: Niger (NER), iterations: 1
# Processed: Nicaragua (NIC), iterations: 1
# Processed: New Zealand (NZL), iterations: 3,2,2,2
# Processed: Niue (NIU), iterations: 1
# Processed: Cook Islands (COK), iterations: 1
# Processed: Netherlands (NLD), iterations: 2,2,2
# Processed: Aruba (ABW), iterations: 1
# Processed: Curaçao (CUW), iterations: 1
# Processed: Nepal (NPL), iterations: 1
# Processed: Nauru (NRU), iterations: 1
# Processed: Namibia (NAM), iterations: 1
# Processed: Mozambique (MOZ), iterations: 1
# Processed: Morocco (MAR), iterations: 1
# Processed: Western Sahara (ESH), iterations: 1
# Processed: Montenegro (MNE), iterations: 1
# Processed: Mongolia (MNG), iterations: 1
# Processed: Moldova (MDA), iterations: 1
# Processed: Monaco (MCO), iterations: 1
# Processed: Mexico (MEX), iterations: 2
# Processed: Mauritius (MUS), iterations: 1
# Processed: Mauritania (MRT), iterations: 2
# Processed: Malta (MLT), iterations: 2
# Processed: Mali (MLI), iterations: 1
# Processed: Maldives (MDV), iterations: 2
# Processed: Malaysia (MYS), iterations: 2,2
# Processed: Malawi (MWI), iterations: 2
# Processed: Madagascar (MDG), iterations: 2
# Processed: Macedonia (MKD), iterations: 1
# Processed: Luxembourg (LUX), iterations: 1
# Processed: Lithuania (LTU), iterations: 2
# Processed: Liechtenstein (LIE), iterations: 1
# Processed: Libya (LBY), iterations: 1
# Processed: Liberia (LBR), iterations: 1
# Processed: Lesotho (LSO), iterations: 1
# Processed: Lebanon (LBN), iterations: 1
# Processed: Latvia (LVA), iterations: 1
# Processed: Laos (LAO), iterations: 1
# Processed: Kyrgyzstan (KGZ), iterations: 1
# Processed: Kuwait (KWT), iterations: 2
# Processed: Kosovo (-99), iterations: 1
# Processed: Kiribati (KIR), iterations: 2,3,2,2,2
# Processed: Kenya (KEN), iterations: 2
# Processed: Kazakhstan (KAZ), iterations: 2
# Processed: Jordan (JOR), iterations: 1
# Processed: Japan (JPN), iterations: 4
# Processed: Jamaica (JAM), iterations: 1
# Processed: Italy (ITA), iterations: 2
# Processed: Israel (ISR), iterations: 1
# Processed: Palestine (PSE), iterations: 2
# Processed: Ireland (IRL), iterations: 2
# Processed: Iraq (IRQ), iterations: 1
# Processed: Iran (IRN), iterations: 2
# Processed: Indonesia (IDN), iterations: 5
# Processed: India (IND), iterations: 2
# Processed: Iceland (ISL), iterations: 1
# Processed: Hungary (HUN), iterations: 1
# Processed: Honduras (HND), iterations: 2
# Processed: Haiti (HTI), iterations: 2
# Processed: Guyana (GUY), iterations: 1
# Processed: Guinea-Bissau (GNB), iterations: 2
# Processed: Guinea (GIN), iterations: 1
# Processed: Guatemala (GTM), iterations: 1
# Processed: Grenada (GRD), iterations: 1
# Processed: Greece (GRC), iterations: 2
# Processed: Ghana (GHA), iterations: 1
# Processed: Germany (DEU), iterations: 2
# Processed: Georgia (GEO), iterations: 1
# Processed: Gambia (GMB), iterations: 1
# Processed: Gabon (GAB), iterations: 1
# Processed: France (-99), iterations: 2,2,2,2,2
# Processed: Saint Pierre and Miquelon (SPM), iterations: 2
# Processed: Wallis and Futuna (WLF), iterations: 2
# Processed: Saint Martin (MAF), iterations: 1
# Processed: Saint Barthelemy (BLM), iterations: 1
# Processed: French Polynesia (PYF), iterations: 4,2
# Processed: New Caledonia (NCL), iterations: 2
# Processed: French Southern and Antarctic Lands (ATF), iterations: 2,2
# Processed: Aland (ALA), iterations: 2
# Processed: Finland (FIN), iterations: 2
# Processed: Fiji (FJI), iterations: 3,2
# Processed: Ethiopia (ETH), iterations: 1
# Processed: Estonia (EST), iterations: 2
# Processed: Eritrea (ERI), iterations: 2
# Processed: Equatorial Guinea (GNQ), iterations: 2
# Processed: El Salvador (SLV), iterations: 1
# Processed: Egypt (EGY), iterations: 1
# Processed: Ecuador (ECU), iterations: 2,2
# Processed: Dominican Republic (DOM), iterations: 1
# Processed: Dominica (DMA), iterations: 1
# Processed: Djibouti (DJI), iterations: 1
# Processed: Greenland (GRL), iterations: 2
# Processed: Faroe Islands (FRO), iterations: 2
# Processed: Denmark (DNK), iterations: 2
# Processed: Czechia (CZE), iterations: 1
# Processed: Northern Cyprus (-99), iterations: 1
# Processed: Cyprus (CYP), iterations: 1
# Processed: Cuba (CUB), iterations: 2
# Processed: Croatia (HRV), iterations: 2
# Processed: Ivory Coast (CIV), iterations: 2
# Processed: Costa Rica (CRI), iterations: 1
# Processed: Democratic Republic of the Congo (COD), iterations: 1
# Processed: Republic of the Congo (COG), iterations: 1
# Processed: Comoros (COM), iterations: 2
# Processed: Colombia (COL), iterations: 2
# Processed: China (CHN), iterations: 2
# Processed: Macao S.A.R (MAC), iterations: 1
# Processed: Hong Kong S.A.R. (HKG), iterations: 2
# Processed: Chile (CHL), iterations: 2,2
# Processed: Chad (TCD), iterations: 1
# Processed: Central African Republic (CAF), iterations: 1
# Processed: Cabo Verde (CPV), iterations: 2
# Processed: Canada (CAN), iterations: 7
# Processed: Cameroon (CMR), iterations: 1
# Processed: Cambodia (KHM), iterations: 2
# Processed: Myanmar (MMR), iterations: 2
# Processed: Burundi (BDI), iterations: 1
# Processed: Burkina Faso (BFA), iterations: 1
# Processed: Bulgaria (BGR), iterations: 1
# Processed: Brunei (BRN), iterations: 2
# Processed: Brazil (BRA), iterations: 2
# Processed: Botswana (BWA), iterations: 1
# Processed: Bosnia and Herzegovina (BIH), iterations: 1
# Processed: Bolivia (BOL), iterations: 1
# Processed: Bhutan (BTN), iterations: 1
# Processed: Benin (BEN), iterations: 1
# Processed: Belize (BLZ), iterations: 2
# Processed: Belgium (BEL), iterations: 1
# Processed: Belarus (BLR), iterations: 1
# Processed: Barbados (BRB), iterations: 1
# Processed: Bangladesh (BGD), iterations: 2
# Processed: Bahrain (BHR), iterations: 1
# Processed: The Bahamas (BHS), iterations: 3
# Processed: Azerbaijan (AZE), iterations: 2
# Processed: Austria (AUT), iterations: 1
# Processed: Australia (AUS), iterations: 3,2
# Processed: Indian Ocean Territories (-99), iterations: 2,2
# Processed: Heard Island and McDonald Islands (HMD), iterations: 1
# Processed: Norfolk Island (NFK), iterations: 1
# Processed: Ashmore and Cartier Islands (-99), iterations: 1
# Processed: Armenia (ARM), iterations: 2
# Processed: Argentina (ARG), iterations: 2
# Processed: Antigua and Barbuda (ATG), iterations: 2
# Processed: Angola (AGO), iterations: 2
# Processed: Andorra (AND), iterations: 1
# Processed: Algeria (DZA), iterations: 1
# Processed: Albania (ALB), iterations: 1
# Processed: Afghanistan (AFG), iterations: 1
# Processed: Siachen Glacier (-99), iterations: 1
# Processed: Antarctica (ATA), iterations: 3
# Processed: Sint Maarten (SXM), iterations: 1

# %% [markdown]
# # Annotation of country parts
# The following two cells intiialize an ipyleaflet map, that interactively lets you annotate the country parts. use the following controls:
# - Zoom via slider OR **mouse wheel**.
# - Click the **Next** and **Previous** buttons to jump from country part to country part.
# - The **Country** textfield shows you to what country the current country prt belongt to. It is not editable.
# - Enter a fitting name (e.g. Alaska, Azores) for the country part into the textfield **Name** in the upper right.
# - **Note:** Each time you navigate from one place to another, your changes are automatically saved in memory as well as a pickle object of the list.

# %%
m = Map(center=(0,0), zoom=3, scroll_wheel_zoom=True, zoom_control=False, basemap=basemaps.Esri.WorldStreetMap)
marker = Marker(location=(0,0), draggable=False)
m.add_layer(marker)

polygon = Polygon(
    locations=[(0,0)],
    color="green",
    fill_color="green"
)
m.add_layer(polygon)

zoom_slider = widgets.IntSlider(description='Zoom level:', min=0, max=15, value=3)
widgets.jslink((zoom_slider, 'value'), (m, 'zoom'))
widget_control_zoom = WidgetControl(widget=zoom_slider, position='topleft')
m.add_control(widget_control_zoom)

country_text = widgets.Text(
    value='',
    placeholder='',
    description='Country:',
    disabled=True,
    layout={'width': '500px'}
)

text_input = widgets.Text(
    value='',
    placeholder='',
    description='Name:',
    disabled=False,
    layout={'width': '500px'}
)

goto_next = widgets.Button(
    description='Next',
    disabled=False,
    button_style='',
    tooltip='Next geometry',
    icon=''
)

goto_pevious = widgets.Button(
    description='Previous',
    disabled=False,
    button_style='',
    tooltip='Prevous geometry',
    icon=''
)

# %%
index = 0

def goto_index(index):
    global polygon
    
    text_input.value = country_list[index]['name']
    country_text.value = country_list[index]['country']
    centroid = country_list[index]['geometry'].centroid.iloc[0]
    center = (centroid.y, centroid.x)
    
    locations = []
    if country_list[index]['geometry'].iloc[0].geom_type == 'Polygon':
        poly = country_list[index]['geometry'].iloc[0]
        locations = [(y,x) for y,x in zip(poly.exterior.coords.xy[1], poly.exterior.coords.xy[0])]
    if country_list[index]['geometry'].iloc[0].geom_type == 'MultiPolygon':
        for poly in country_list[index]['geometry'].iloc[0]:
            locations.append([(y,x) for y,x in zip(poly.exterior.coords.xy[1], poly.exterior.coords.xy[0])])
    m.remove_layer(polygon)
    polygon = Polygon(
        locations=locations,
        color="green",
        fill_color="green"
    )
    m.add_layer(polygon)
    m.center = center
    marker.location = center
    
def next_clicked(button):
    global index
    country_list[index]['name'] = text_input.value
    pickle.dump(country_list, open('country_list.p', 'wb'))
    index += 1
    if index == len(country_list):
        index = 0
    goto_index(index)
    
def previous_clicked(button):
    global index
    country_list[index]['name'] = text_input.value
    pickle.dump(country_list, open('country_list.p', 'wb'))
    index -= 1
    if index < 0:
        index = len(country_list) - 1
    goto_index(index)
    
goto_next.on_click(next_clicked)
goto_pevious.on_click(previous_clicked)

widget_control_country = WidgetControl(widget=country_text, position='topright')
m.add_control(widget_control_country)
widget_control_input = WidgetControl(widget=text_input, position='topright')
m.add_control(widget_control_input)
widget_control_next = WidgetControl(widget=goto_next, position='bottomright')
m.add_control(widget_control_next)
widget_control_previous = WidgetControl(widget=goto_pevious, position='bottomleft')
m.add_control(widget_control_previous)

goto_index(index)
m
# Out:
# Map(basemap={'url': 'http://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{…

# %% [markdown]
# Running the cell above should show a map. If this is not the case, try to reboot your jupyter notebook.

# %% [markdown]
# # Define Layout

# %%
nrows = 2
ncols = 3

# %%
grid = plt.GridSpec(nrows, ncols)

# %%
pickle.load(open('country_list.p', 'rb'))
# Out:
# [{'country': 'Zimbabwe',
#   'ISO_A3': 'ZWE',
#   'name': 'Zimbabwe',
#   'geometry': 0    POLYGON ((31.287890625 -22.40205078125001, 31....
#   dtype: object},
#  {'country': 'Zambia',
#   'ISO_A3': 'ZMB',
#   'name': 'Zambia',
#   'geometry': 0    POLYGON ((30.39609375000001 -15.64306640625002...
#   dtype: object},
#  {'country': 'Yemen',
#   'ISO_A3': 'YEM',
#   'name': 'Yemen',
#   'geometry': 0    (POLYGON ((53.76318359374999 12.63681640624997...
#   dtype: object},
#  {'country': 'Vietnam',
#   'ISO_A3': 'VNM',
#   'name': 'Vietnam',
#   'geometry': 0    (POLYGON ((107.16767578125 10.39716796875, 107...
#   dtype: object},
#  {'country': 'Venezuela',
#   'ISO_A3': 'VEN',
#   'name': 'Venezuela',
#   'geometry': 0    (POLYGON ((-60.99790039062498 8.86733398437498...
#   dtype: object},
#  {'country': 'Vatican',
#   'ISO_A3': 'VAT',
#   'name': 'Vatican',
#   'geometry': 0    POLYGON ((12.43916015625002 41.89838867187499,...
#   dtype: object},
#  {'country': 'Vanuatu',
#   'ISO_A3': 'VUT',
#   'name': 'Vanuatu',
#   'geometry': 0    (POLYGON ((169.8962890625 -20.18662109374999, ...
#   dtype: object},
#  {'country': 'Uzbekistan',
#   'ISO_A3': 'UZB',
#   'name': 'Uzbekistan',
#   'geometry': 0    (POLYGON ((71.20615234375002 39.89257812499999...
#   dtype: object},
#  {'country': 'Uruguay',
#   'ISO_A3': 'URY',
#   'name': 'Uruguay',
#   'geometry': 0    POLYGON ((-53.37060546875001 -33.7421875000000...
#   dtype: object},
#  {'country': 'Federated States of Micronesia',
#   'ISO_A3': 'FSM',
#   'name': 'Federated States of Micronesia',
#   'geometry': 0    POLYGON ((158.31484375 6.813671875000009, 158....
#   dtype: object},
#  {'country': 'Federated States of Micronesia',
#   'ISO_A3': 'FSM',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((138.14267578125 9.500683593749999, 1...
#   dtype: object},
#  {'country': 'Federated States of Micronesia',
#   'ISO_A3': 'FSM',
#   'name': 'Unknown 1',
#   'geometry': 0    (POLYGON ((151.64775390625 7.346191406249996, ...
#   dtype: object},
#  {'country': 'Federated States of Micronesia',
#   'ISO_A3': 'FSM',
#   'name': 'Unknown 2',
#   'geometry': 0    POLYGON ((162.983203125 5.325732421874984, 162...
#   dtype: object},
#  {'country': 'Marshall Islands',
#   'ISO_A3': 'MHL',
#   'name': 'Marshall Islands',
#   'geometry': 0    (POLYGON ((169.63505859375 5.830078124999984, ...
#   dtype: object},
#  {'country': 'Northern Mariana Islands',
#   'ISO_A3': 'MNP',
#   'name': 'Northern Mariana Islands',
#   'geometry': 0    (POLYGON ((145.26484375 14.15810546874998, 145...
#   dtype: object},
#  {'country': 'United States Virgin Islands',
#   'ISO_A3': 'VIR',
#   'name': 'United States Virgin Islands',
#   'geometry': 0    (POLYGON ((-64.76562500000001 17.7943359375000...
#   dtype: object},
#  {'country': 'Guam',
#   'ISO_A3': 'GUM',
#   'name': 'Guam',
#   'geometry': 0    POLYGON ((144.741796875 13.25927734374999, 144...
#   dtype: object},
#  {'country': 'American Samoa',
#   'ISO_A3': 'ASM',
#   'name': 'American Samoa',
#   'geometry': 0    POLYGON ((-170.72626953125 -14.351171875, -170...
#   dtype: object},
#  {'country': 'Puerto Rico',
#   'ISO_A3': 'PRI',
#   'name': 'Puerto Rico',
#   'geometry': 0    (POLYGON ((-67.87246093750001 18.0598632812499...
#   dtype: object},
#  {'country': 'United States of America',
#   'ISO_A3': 'USA',
#   'name': 'United States of America',
#   'geometry': 0    (POLYGON ((-81.78383789062498 24.5445800781249...
#   dtype: object},
#  {'country': 'United States of America',
#   'ISO_A3': 'USA',
#   'name': 'Alaska',
#   'geometry': 0    (POLYGON ((-176.28671875 51.7919921875, -176.3...
#   dtype: object},
#  {'country': 'United States of America',
#   'ISO_A3': 'USA',
#   'name': 'Unknown 1',
#   'geometry': 0    (POLYGON ((-155.58134765625 19.01201171875001,...
#   dtype: object},
#  {'country': 'United States of America',
#   'ISO_A3': 'USA',
#   'name': 'Unknown 2',
#   'geometry': 0    (POLYGON ((179.4515625 51.372607421875, 179.27...
#   dtype: object},
#  {'country': 'South Georgia and the Islands',
#   'ISO_A3': 'SGS',
#   'name': 'South Georgia and the Islands',
#   'geometry': 0    POLYGON ((-37.10332031249998 -54.0656250000000...
#   dtype: object},
#  {'country': 'South Georgia and the Islands',
#   'ISO_A3': 'SGS',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((-26.26411132812498 -58.4351562499999...
#   dtype: object},
#  {'country': 'British Indian Ocean Territory',
#   'ISO_A3': 'IOT',
#   'name': 'British Indian Ocean Territory',
#   'geometry': 0    POLYGON ((72.49199218750003 -7.377441406250028...
#   dtype: object},
#  {'country': 'Saint Helena',
#   'ISO_A3': 'SHN',
#   'name': 'Saint Helena',
#   'geometry': 0    POLYGON ((-5.692138671874991 -15.9977539062500...
#   dtype: object},
#  {'country': 'Saint Helena',
#   'ISO_A3': 'SHN',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((-14.36435546874996 -7.97431640625002...
#   dtype: object},
#  {'country': 'Pitcairn Islands',
#   'ISO_A3': 'PCN',
#   'name': 'Pitcairn Islands',
#   'geometry': 0    POLYGON ((-128.290087890625 -24.39736328125002...
#   dtype: object},
#  {'country': 'Anguilla',
#   'ISO_A3': 'AIA',
#   'name': 'Anguilla',
#   'geometry': 0    POLYGON ((-63.00122070312499 18.22177734375, -...
#   dtype: object},
#  {'country': 'Falkland Islands',
#   'ISO_A3': 'FLK',
#   'name': 'Falkland Islands',
#   'geometry': 0    (POLYGON ((-60.11171875000001 -51.395898437499...
#   dtype: object},
#  {'country': 'Cayman Islands',
#   'ISO_A3': 'CYM',
#   'name': 'Cayman Islands',
#   'geometry': 0    (POLYGON ((-81.36953124999999 19.3488769531250...
#   dtype: object},
#  {'country': 'Bermuda',
#   'ISO_A3': 'BMU',
#   'name': 'Bermuda',
#   'geometry': 0    POLYGON ((-64.73027343749999 32.29345703124999...
#   dtype: object},
#  {'country': 'British Virgin Islands',
#   'ISO_A3': 'VGB',
#   'name': 'British Virgin Islands',
#   'geometry': 0    (POLYGON ((-64.59365234374999 18.4028320312499...
#   dtype: object},
#  {'country': 'Turks and Caicos Islands',
#   'ISO_A3': 'TCA',
#   'name': 'Turks and Caicos Islands',
#   'geometry': 0    (POLYGON ((-71.66142578124997 21.7652343749999...
#   dtype: object},
#  {'country': 'Montserrat',
#   'ISO_A3': 'MSR',
#   'name': 'Montserrat',
#   'geometry': 0    POLYGON ((-62.14843750000001 16.74033203125, -...
#   dtype: object},
#  {'country': 'Jersey',
#   'ISO_A3': 'JEY',
#   'name': 'Jersey',
#   'geometry': 0    POLYGON ((-2.018652343749981 49.23125, -2.0099...
#   dtype: object},
#  {'country': 'Guernsey',
#   'ISO_A3': 'GGY',
#   'name': 'Guernsey',
#   'geometry': 0    POLYGON ((-2.512304687499989 49.49453124999999...
#   dtype: object},
#  {'country': 'Isle of Man',
#   'ISO_A3': 'IMN',
#   'name': 'Isle of Man',
#   'geometry': 0    POLYGON ((-4.412060546874998 54.18535156249999...
#   dtype: object},
#  {'country': 'United Kingdom',
#   'ISO_A3': 'GBR',
#   'name': 'United Kingdom',
#   'geometry': 0    (POLYGON ((-6.218017578125002 54.0887207031249...
#   dtype: object},
#  {'country': 'United Arab Emirates',
#   'ISO_A3': 'ARE',
#   'name': 'United Arab Emirates',
#   'geometry': 0    (POLYGON ((54.46542968750001 24.44277343749999...
#   dtype: object},
#  {'country': 'Ukraine',
#   'ISO_A3': 'UKR',
#   'name': 'Ukraine',
#   'geometry': 0    (POLYGON ((32.01220703125001 46.20390624999999...
#   dtype: object},
#  {'country': 'Uganda',
#   'ISO_A3': 'UGA',
#   'name': 'Uganda',
#   'geometry': 0    POLYGON ((33.90322265625002 -1.002050781250017...
#   dtype: object},
#  {'country': 'Turkmenistan',
#   'ISO_A3': 'TKM',
#   'name': 'Turkmenistan',
#   'geometry': 0    (POLYGON ((53.10957031250001 38.80307617187497...
#   dtype: object},
#  {'country': 'Turkey',
#   'ISO_A3': 'TUR',
#   'name': 'Turkey',
#   'geometry': 0    (POLYGON ((25.97001953125002 40.13632812500001...
#   dtype: object},
#  {'country': 'Tunisia',
#   'ISO_A3': 'TUN',
#   'name': 'Tunisia',
#   'geometry': 0    (POLYGON ((11.27802734375001 34.75380859374997...
#   dtype: object},
#  {'country': 'Trinidad and Tobago',
#   'ISO_A3': 'TTO',
#   'name': 'Trinidad and Tobago',
#   'geometry': 0    (POLYGON ((-61.01210937500001 10.1343261718749...
#   dtype: object},
#  {'country': 'Tonga',
#   'ISO_A3': 'TON',
#   'name': 'Tonga',
#   'geometry': 0    (POLYGON ((-174.913134765625 -21.30048828125, ...
#   dtype: object},
#  {'country': 'Togo',
#   'ISO_A3': 'TGO',
#   'name': 'Togo',
#   'geometry': 0    POLYGON ((0.900488281250019 10.99326171875, 0....
#   dtype: object},
#  {'country': 'East Timor',
#   'ISO_A3': 'TLS',
#   'name': 'East Timor',
#   'geometry': 0    (POLYGON ((124.036328125 -9.341601562500021, 1...
#   dtype: object},
#  {'country': 'Thailand',
#   'ISO_A3': 'THA',
#   'name': 'Thailand',
#   'geometry': 0    (POLYGON ((100.070703125 9.586035156249967, 10...
#   dtype: object},
#  {'country': 'United Republic of Tanzania',
#   'ISO_A3': 'TZA',
#   'name': 'United Republic of Tanzania',
#   'geometry': 0    (POLYGON ((39.71132812500003 -7.97744140624999...
#   dtype: object},
#  {'country': 'Tajikistan',
#   'ISO_A3': 'TJK',
#   'name': 'Tajikistan',
#   'geometry': 0    (POLYGON ((67.75898437500001 37.17221679687498...
#   dtype: object},
#  {'country': 'Taiwan',
#   'ISO_A3': 'TWN',
#   'name': 'Taiwan',
#   'geometry': 0    (POLYGON ((121.0087890625 22.620361328125, 120...
#   dtype: object},
#  {'country': 'Syria',
#   'ISO_A3': 'SYR',
#   'name': 'Syria',
#   'geometry': 0    POLYGON ((35.89267578124999 35.91655273437497,...
#   dtype: object},
#  {'country': 'Switzerland',
#   'ISO_A3': 'CHE',
#   'name': 'Switzerland',
#   'geometry': 0    POLYGON ((9.524023437500006 47.52421874999999,...
#   dtype: object},
#  {'country': 'Sweden',
#   'ISO_A3': 'SWE',
#   'name': 'Sweden',
#   'geometry': 0    (POLYGON ((18.59541015625002 59.47036132812498...
#   dtype: object},
#  {'country': 'eSwatini',
#   'ISO_A3': 'SWZ',
#   'name': 'eSwatini',
#   'geometry': 0    POLYGON ((31.9482421875 -25.95761718749998, 31...
#   dtype: object},
#  {'country': 'Suriname',
#   'ISO_A3': 'SUR',
#   'name': 'Suriname',
#   'geometry': 0    POLYGON ((-54.15595703125 5.358984374999999, -...
#   dtype: object},
#  {'country': 'South Sudan',
#   'ISO_A3': 'SSD',
#   'name': 'South Sudan',
#   'geometry': 0    POLYGON ((33.97607421875 4.22021484375, 33.741...
#   dtype: object},
#  {'country': 'Sudan',
#   'ISO_A3': 'SDN',
#   'name': 'Sudan',
#   'geometry': 0    POLYGON ((34.07812500000001 9.461523437499991,...
#   dtype: object},
#  {'country': 'Sri Lanka',
#   'ISO_A3': 'LKA',
#   'name': 'Sri Lanka',
#   'geometry': 0    (POLYGON ((79.98232421875004 9.812695312499985...
#   dtype: object},
#  {'country': 'Spain',
#   'ISO_A3': 'ESP',
#   'name': 'Spain',
#   'geometry': 0    (POLYGON ((4.293652343750017 39.84184570312499...
#   dtype: object},
#  {'country': 'Spain',
#   'ISO_A3': 'ESP',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((-17.88793945312499 27.8095703124999...
#   dtype: object},
#  {'country': 'South Korea',
#   'ISO_A3': 'KOR',
#   'name': 'South Korea',
#   'geometry': 0    (POLYGON ((126.326953125 33.22363281249997, 12...
#   dtype: object},
#  {'country': 'South Africa',
#   'ISO_A3': 'ZAF',
#   'name': 'South Africa',
#   'geometry': 0    POLYGON ((29.36484374999999 -22.19394531250001...
#   dtype: object},
#  {'country': 'South Africa',
#   'ISO_A3': 'ZAF',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((37.85693359375002 -46.94423828124999...
#   dtype: object},
#  {'country': 'Somalia',
#   'ISO_A3': 'SOM',
#   'name': 'Somalia',
#   'geometry': 0    POLYGON ((41.53271484374999 -1.695312500000015...
#   dtype: object},
#  {'country': 'Somaliland',
#   'ISO_A3': '-99',
#   'name': 'Somaliland',
#   'geometry': 0    POLYGON ((48.93857421875001 11.25844726562497,...
#   dtype: object},
#  {'country': 'Solomon Islands',
#   'ISO_A3': 'SLB',
#   'name': 'Solomon Islands',
#   'geometry': 0    (POLYGON ((160.57626953125 -11.79785156250002,...
#   dtype: object},
#  {'country': 'Slovakia',
#   'ISO_A3': 'SVK',
#   'name': 'Slovakia',
#   'geometry': 0    POLYGON ((22.538671875 49.07270507812498, 22.5...
#   dtype: object},
#  {'country': 'Slovenia',
#   'ISO_A3': 'SVN',
#   'name': 'Slovenia',
#   'geometry': 0    POLYGON ((16.5162109375 46.49990234374999, 16....
#   dtype: object},
#  {'country': 'Singapore',
#   'ISO_A3': 'SGP',
#   'name': 'Singapore',
#   'geometry': 0    POLYGON ((103.9697265625 1.331445312499977, 10...
#   dtype: object},
#  {'country': 'Sierra Leone',
#   'ISO_A3': 'SLE',
#   'name': 'Sierra Leone',
#   'geometry': 0    (POLYGON ((-12.52607421874997 7.43632812499999...
#   dtype: object},
#  {'country': 'Seychelles',
#   'ISO_A3': 'SYC',
#   'name': 'Seychelles',
#   'geometry': 0    POLYGON ((55.54033203125 -4.693066406250017, 5...
#   dtype: object},
#  {'country': 'Republic of Serbia',
#   'ISO_A3': 'SRB',
#   'name': 'Republic of Serbia',
#   'geometry': 0    POLYGON ((21.36005859375001 44.82666015625001,...
#   dtype: object},
#  {'country': 'Senegal',
#   'ISO_A3': 'SEN',
#   'name': 'Senegal',
#   'geometry': 0    POLYGON ((-12.28061523437499 14.80903320312498...
#   dtype: object},
#  {'country': 'Saudi Arabia',
#   'ISO_A3': 'SAU',
#   'name': 'Saudi Arabia',
#   'geometry': 0    (POLYGON ((41.98769531250002 16.71562499999999...
#   dtype: object},
#  {'country': 'São Tomé and Principe',
#   'ISO_A3': 'STP',
#   'name': 'São Tomé and Principe',
#   'geometry': 0    (POLYGON ((6.659960937500023 0.120654296875001...
#   dtype: object},
#  {'country': 'San Marino',
#   'ISO_A3': 'SMR',
#   'name': 'San Marino',
#   'geometry': 0    POLYGON ((12.48525390625002 43.90141601562497,...
#   dtype: object},
#  {'country': 'Samoa',
#   'ISO_A3': 'WSM',
#   'name': 'Samoa',
#   'geometry': 0    (POLYGON ((-171.4541015625 -14.04648437499999,...
#   dtype: object},
#  {'country': 'Saint Vincent and the Grenadines',
#   'ISO_A3': 'VCT',
#   'name': 'Saint Vincent and the Grenadines',
#   'geometry': 0    (POLYGON ((-61.33437499999997 12.6952148437499...
#   dtype: object},
#  {'country': 'Saint Lucia',
#   'ISO_A3': 'LCA',
#   'name': 'Saint Lucia',
#   'geometry': 0    POLYGON ((-60.89521484374998 13.82197265624999...
#   dtype: object},
#  {'country': 'Saint Kitts and Nevis',
#   'ISO_A3': 'KNA',
#   'name': 'Saint Kitts and Nevis',
#   'geometry': 0    (POLYGON ((-62.5322265625 17.12187499999999, -...
#   dtype: object},
#  {'country': 'Rwanda',
#   'ISO_A3': 'RWA',
#   'name': 'Rwanda',
#   'geometry': 0    POLYGON ((29.57695312500002 -1.387890625000022...
#   dtype: object},
#  {'country': 'Russia',
#   'ISO_A3': 'RUS',
#   'name': 'Russia',
#   'geometry': 0    (POLYGON ((70.02070312500003 66.50219726562501...
#   dtype: object},
#  {'country': 'Russia',
#   'ISO_A3': 'RUS',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((-179.79853515625 68.94042968749999, ...
#   dtype: object},
#  {'country': 'Russia',
#   'ISO_A3': 'RUS',
#   'name': 'Unknown 1',
#   'geometry': 0    POLYGON ((-178.87646484375 71.57705078124998, ...
#   dtype: object},
#  {'country': 'Russia',
#   'ISO_A3': 'RUS',
#   'name': 'Unknown 2',
#   'geometry': 0    POLYGON ((20.95781250000003 55.27890624999998,...
#   dtype: object},
#  {'country': 'Romania',
#   'ISO_A3': 'ROU',
#   'name': 'Romania',
#   'geometry': 0    POLYGON ((28.21249999999999 45.45043945312499,...
#   dtype: object},
#  {'country': 'Qatar',
#   'ISO_A3': 'QAT',
#   'name': 'Qatar',
#   'geometry': 0    POLYGON ((51.26796875000003 24.60722656249999,...
#   dtype: object},
#  {'country': 'Portugal',
#   'ISO_A3': 'PRT',
#   'name': 'Portugal',
#   'geometry': 0    POLYGON ((-8.777148437499996 41.94106445312499...
#   dtype: object},
#  {'country': 'Portugal',
#   'ISO_A3': 'PRT',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((-25.02734374999999 36.9599609374999...
#   dtype: object},
#  {'country': 'Portugal',
#   'ISO_A3': 'PRT',
#   'name': 'Unknown 1',
#   'geometry': 0    POLYGON ((-17.19086914062498 32.86860351562499...
#   dtype: object},
#  {'country': 'Poland',
#   'ISO_A3': 'POL',
#   'name': 'Poland',
#   'geometry': 0    POLYGON ((23.60527343750003 51.517919921875, 2...
#   dtype: object},
#  {'country': 'Philippines',
#   'ISO_A3': 'PHL',
#   'name': 'Philippines',
#   'geometry': 0    (POLYGON ((120.250390625 5.256591796874993, 12...
#   dtype: object},
#  {'country': 'Peru',
#   'ISO_A3': 'PER',
#   'name': 'Peru',
#   'geometry': 0    POLYGON ((-69.96591796874999 -4.23593750000002...
#   dtype: object},
#  {'country': 'Paraguay',
#   'ISO_A3': 'PRY',
#   'name': 'Paraguay',
#   'geometry': 0    POLYGON ((-58.15976562499998 -20.1646484375000...
#   dtype: object},
#  {'country': 'Papua New Guinea',
#   'ISO_A3': 'PNG',
#   'name': 'Papua New Guinea',
#   'geometry': 0    (POLYGON ((153.5361328125 -11.47617187500001, ...
#   dtype: object},
#  {'country': 'Panama',
#   'ISO_A3': 'PAN',
#   'name': 'Panama',
#   'geometry': 0    (POLYGON ((-82.23349609374999 9.38071289062499...
#   dtype: object},
#  {'country': 'Palau',
#   'ISO_A3': 'PLW',
#   'name': 'Palau',
#   'geometry': 0    (POLYGON ((131.17236328125 3.026220703124981, ...
#   dtype: object},
#  {'country': 'Pakistan',
#   'ISO_A3': 'PAK',
#   'name': 'Pakistan',
#   'geometry': 0    POLYGON ((76.76689453124997 35.66171875000001,...
#   dtype: object},
#  {'country': 'Oman',
#   'ISO_A3': 'OMN',
#   'name': 'Oman',
#   'geometry': 0    (POLYGON ((58.72207031250002 20.21875000000001...
#   dtype: object},
#  {'country': 'Norway',
#   'ISO_A3': '-99',
#   'name': 'Norway',
#   'geometry': 0    (POLYGON ((11.23144531249998 64.86586914062499...
#   dtype: object},
#  {'country': 'Norway',
#   'ISO_A3': '-99',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((26.87597656249999 78.64892578125001...
#   dtype: object},
#  {'country': 'Norway',
#   'ISO_A3': '-99',
#   'name': 'Unknown 1',
#   'geometry': 0    POLYGON ((-8.953564453124976 70.83916015625002...
#   dtype: object},
#  {'country': 'Norway',
#   'ISO_A3': '-99',
#   'name': 'Unknown 2',
#   'geometry': 0    POLYGON ((19.2193359375 74.39101562499998, 19....
#   dtype: object},
#  {'country': 'North Korea',
#   'ISO_A3': 'PRK',
#   'name': 'North Korea',
#   'geometry': 0    (POLYGON ((124.9052734375 39.53627929687496, 1...
#   dtype: object},
#  {'country': 'Nigeria',
#   'ISO_A3': 'NGA',
#   'name': 'Nigeria',
#   'geometry': 0    (POLYGON ((7.300781249999998 4.418164062499972...
#   dtype: object},
#  {'country': 'Niger',
#   'ISO_A3': 'NER',
#   'name': 'Niger',
#   'geometry': 0    POLYGON ((13.60634765625004 13.70458984374999,...
#   dtype: object},
#  {'country': 'Nicaragua',
#   'ISO_A3': 'NIC',
#   'name': 'Nicaragua',
#   'geometry': 0    POLYGON ((-83.15751953124999 14.99306640624999...
#   dtype: object},
#  {'country': 'New Zealand',
#   'ISO_A3': 'NZL',
#   'name': 'New Zealand',
#   'geometry': 0    (POLYGON ((168.1449218750001 -46.8622070312499...
#   dtype: object},
#  {'country': 'New Zealand',
#   'ISO_A3': 'NZL',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((-176.17646484375 -44.32167968749999...
#   dtype: object},
#  {'country': 'New Zealand',
#   'ISO_A3': 'NZL',
#   'name': 'Unknown 1',
#   'geometry': 0    (POLYGON ((169.17822265625 -52.49726562500002,...
#   dtype: object},
#  {'country': 'New Zealand',
#   'ISO_A3': 'NZL',
#   'name': 'Unknown 2',
#   'geometry': 0    (POLYGON ((-171.18642578125 -9.35546875, -171....
#   dtype: object},
#  {'country': 'Niue',
#   'ISO_A3': 'NIU',
#   'name': 'Niue',
#   'geometry': 0    POLYGON ((-169.80341796875 -19.08300781250001,...
#   dtype: object},
#  {'country': 'Cook Islands',
#   'ISO_A3': 'COK',
#   'name': 'Cook Islands',
#   'geometry': 0    POLYGON ((-159.74052734375 -21.24921875000002,...
#   dtype: object},
#  {'country': 'Netherlands',
#   'ISO_A3': 'NLD',
#   'name': 'Netherlands',
#   'geometry': 0    (POLYGON ((4.886132812500037 53.070703125, 4.7...
#   dtype: object},
#  {'country': 'Netherlands',
#   'ISO_A3': 'NLD',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((-68.20581054687499 12.14458007812499...
#   dtype: object},
#  {'country': 'Netherlands',
#   'ISO_A3': 'NLD',
#   'name': 'Unknown 1',
#   'geometry': 0    (POLYGON ((-62.93750000000001 17.4956542968750...
#   dtype: object},
#  {'country': 'Aruba',
#   'ISO_A3': 'ABW',
#   'name': 'Aruba',
#   'geometry': 0    POLYGON ((-69.89912109374998 12.45200195312498...
#   dtype: object},
#  {'country': 'Curaçao',
#   'ISO_A3': 'CUW',
#   'name': 'Curaçao',
#   'geometry': 0    POLYGON ((-68.75107421874999 12.059765625, -68...
#   dtype: object},
#  {'country': 'Nepal',
#   'ISO_A3': 'NPL',
#   'name': 'Nepal',
#   'geometry': 0    POLYGON ((88.10976562499999 27.87060546874994,...
#   dtype: object},
#  {'country': 'Nauru',
#   'ISO_A3': 'NRU',
#   'name': 'Nauru',
#   'geometry': 0    POLYGON ((166.9583984375001 -0.516601562500005...
#   dtype: object},
#  {'country': 'Namibia',
#   'ISO_A3': 'NAM',
#   'name': 'Namibia',
#   'geometry': 0    POLYGON ((23.38066406250003 -17.64062499999999...
#   dtype: object},
#  {'country': 'Mozambique',
#   'ISO_A3': 'MOZ',
#   'name': 'Mozambique',
#   'geometry': 0    POLYGON ((31.287890625 -22.40205078125001, 31....
#   dtype: object},
#  {'country': 'Morocco',
#   'ISO_A3': 'MAR',
#   'name': 'Morocco',
#   'geometry': 0    POLYGON ((-2.219628906249996 35.10419921875, -...
#   dtype: object},
#  {'country': 'Western Sahara',
#   'ISO_A3': 'ESH',
#   'name': 'Western Sahara',
#   'geometry': 0    POLYGON ((-8.817773437500007 27.655908203125, ...
#   dtype: object},
#  {'country': 'Montenegro',
#   'ISO_A3': 'MNE',
#   'name': 'Montenegro',
#   'geometry': 0    POLYGON ((19.19433593750001 43.53330078124998,...
#   dtype: object},
#  {'country': 'Mongolia',
#   'ISO_A3': 'MNG',
#   'name': 'Mongolia',
#   'geometry': 0    POLYGON ((87.81425781249996 49.16230468749998,...
#   dtype: object},
#  {'country': 'Moldova',
#   'ISO_A3': 'MDA',
#   'name': 'Moldova',
#   'geometry': 0    POLYGON ((26.61894531250001 48.25986328125, 26...
#   dtype: object},
#  {'country': 'Monaco',
#   'ISO_A3': 'MCO',
#   'name': 'Monaco',
#   'geometry': 0    POLYGON ((7.438671874999996 43.75043945312499,...
#   dtype: object},
#  {'country': 'Mexico',
#   'ISO_A3': 'MEX',
#   'name': 'Mexico',
#   'geometry': 0    (POLYGON ((-86.71401367187498 21.2393066406249...
#   dtype: object},
#  {'country': 'Mauritius',
#   'ISO_A3': 'MUS',
#   'name': 'Mauritius',
#   'geometry': 0    POLYGON ((57.65126953125003 -20.48486328125, 5...
#   dtype: object},
#  {'country': 'Mauritania',
#   'ISO_A3': 'MRT',
#   'name': 'Mauritania',
#   'geometry': 0    (POLYGON ((-16.37333984375 19.70644531249999, ...
#   dtype: object},
#  {'country': 'Malta',
#   'ISO_A3': 'MLT',
#   'name': 'Malta',
#   'geometry': 0    (POLYGON ((14.56621093750001 35.85273437500001...
#   dtype: object},
#  {'country': 'Mali',
#   'ISO_A3': 'MLI',
#   'name': 'Mali',
#   'geometry': 0    POLYGON ((-11.38940429687501 12.40439453125, -...
#   dtype: object},
#  {'country': 'Maldives',
#   'ISO_A3': 'MDV',
#   'name': 'Maldives',
#   'geometry': 0    (POLYGON ((73.41660156249999 3.231249999999992...
#   dtype: object},
#  {'country': 'Malaysia',
#   'ISO_A3': 'MYS',
#   'name': 'Malaysia',
#   'geometry': 0    (POLYGON ((111.3892578125001 2.415332031249988...
#   dtype: object},
#  {'country': 'Malaysia',
#   'ISO_A3': 'MYS',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((101.3185546875 2.988476562499996, 1...
#   dtype: object},
#  {'country': 'Malawi',
#   'ISO_A3': 'MWI',
#   'name': 'Malawi',
#   'geometry': 0    (POLYGON ((33.20175781250002 -14.0133789062500...
#   dtype: object},
#  {'country': 'Madagascar',
#   'ISO_A3': 'MDG',
#   'name': 'Madagascar',
#   'geometry': 0    (POLYGON ((49.53828125000002 -12.4321289062500...
#   dtype: object},
#  {'country': 'Macedonia',
#   'ISO_A3': 'MKD',
#   'name': 'Macedonia',
#   'geometry': 0    POLYGON ((21.5625 42.24750976562498, 21.618261...
#   dtype: object},
#  {'country': 'Luxembourg',
#   'ISO_A3': 'LUX',
#   'name': 'Luxembourg',
#   'geometry': 0    POLYGON ((6.116503906250019 50.12099609374999,...
#   dtype: object},
#  {'country': 'Lithuania',
#   'ISO_A3': 'LTU',
#   'name': 'Lithuania',
#   'geometry': 0    (POLYGON ((22.76621093749999 54.35678710937499...
#   dtype: object},
#  {'country': 'Liechtenstein',
#   'ISO_A3': 'LIE',
#   'name': 'Liechtenstein',
#   'geometry': 0    POLYGON ((9.58027343750001 47.057373046875, 9....
#   dtype: object},
#  {'country': 'Libya',
#   'ISO_A3': 'LBY',
#   'name': 'Libya',
#   'geometry': 0    POLYGON ((9.518750000000017 30.22939453124997,...
#   dtype: object},
#  {'country': 'Liberia',
#   'ISO_A3': 'LBR',
#   'name': 'Liberia',
#   'geometry': 0    POLYGON ((-11.50751953124997 6.906542968749987...
#   dtype: object},
#  {'country': 'Lesotho',
#   'ISO_A3': 'LSO',
#   'name': 'Lesotho',
#   'geometry': 0    POLYGON ((28.7369140625 -30.10195312500002, 28...
#   dtype: object},
#  {'country': 'Lebanon',
#   'ISO_A3': 'LBN',
#   'name': 'Lebanon',
#   'geometry': 0    POLYGON ((35.97626953125002 34.62919921874999,...
#   dtype: object},
#  {'country': 'Latvia',
#   'ISO_A3': 'LVA',
#   'name': 'Latvia',
#   'geometry': 0    POLYGON ((26.59355468750002 55.66752929687498,...
#   dtype: object},
#  {'country': 'Laos',
#   'ISO_A3': 'LAO',
#   'name': 'Laos',
#   'geometry': 0    POLYGON ((102.12744140625 22.37919921874998, 1...
#   dtype: object},
#  {'country': 'Kyrgyzstan',
#   'ISO_A3': 'KGZ',
#   'name': 'Kyrgyzstan',
#   'geometry': 0    POLYGON ((70.9580078125 40.23886718749998, 70....
#   dtype: object},
#  {'country': 'Kuwait',
#   'ISO_A3': 'KWT',
#   'name': 'Kuwait',
#   'geometry': 0    (POLYGON ((48.44248046875001 28.54291992187499...
#   dtype: object},
#  {'country': 'Kosovo',
#   'ISO_A3': '-99',
#   'name': 'Kosovo',
#   'geometry': 0    POLYGON ((20.34433593750001 42.82792968750002,...
#   dtype: object},
#  {'country': 'Kiribati',
#   'ISO_A3': 'KIR',
#   'name': 'Kiribati',
#   'geometry': 0    (POLYGON ((-157.342138671875 1.855566406249983...
#   dtype: object},
#  {'country': 'Kiribati',
#   'ISO_A3': 'KIR',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((174.7732421875 -1.211914062500015, ...
#   dtype: object},
#  {'country': 'Kiribati',
#   'ISO_A3': 'KIR',
#   'name': 'Unknown 1',
#   'geometry': 0    (POLYGON ((-155.863818359375 -5.62666015624999...
#   dtype: object},
#  {'country': 'Kiribati',
#   'ISO_A3': 'KIR',
#   'name': 'Unknown 2',
#   'geometry': 0    (POLYGON ((-174.512939453125 -4.67509765625002...
#   dtype: object},
#  {'country': 'Kiribati',
#   'ISO_A3': 'KIR',
#   'name': 'Unknown 3',
#   'geometry': 0    POLYGON ((-151.7826171875 -11.44101562499999, ...
#   dtype: object},
#  {'country': 'Kenya',
#   'ISO_A3': 'KEN',
#   'name': 'Kenya',
#   'geometry': 0    (POLYGON ((40.99443359375002 -2.15839843750002...
#   dtype: object},
#  {'country': 'Kazakhstan',
#   'ISO_A3': 'KAZ',
#   'name': 'Kazakhstan',
#   'geometry': 0    (POLYGON ((52.68242187500003 45.41181640624998...
#   dtype: object},
#  {'country': 'Jordan',
#   'ISO_A3': 'JOR',
#   'name': 'Jordan',
#   'geometry': 0    POLYGON ((35.78730468750003 32.73491210937497,...
#   dtype: object},
#  {'country': 'Japan',
#   'ISO_A3': 'JPN',
#   'name': 'Japan',
#   'geometry': 0    (POLYGON ((123.888671875 24.28012695312498, 12...
#   dtype: object},
#  {'country': 'Jamaica',
#   'ISO_A3': 'JAM',
#   'name': 'Jamaica',
#   'geometry': 0    POLYGON ((-77.261474609375 18.45742187499999, ...
#   dtype: object},
#  {'country': 'Italy',
#   'ISO_A3': 'ITA',
#   'name': 'Italy',
#   'geometry': 0    (POLYGON ((12.05126953124999 36.75703124999999...
#   dtype: object},
#  {'country': 'Israel',
#   'ISO_A3': 'ISR',
#   'name': 'Israel',
#   'geometry': 0    POLYGON ((35.86914062499999 33.43173828124999,...
#   dtype: object},
#  {'country': 'Palestine',
#   'ISO_A3': 'PSE',
#   'name': 'Palestine',
#   'geometry': 0    (POLYGON ((34.47734375 31.58486328124999, 34.5...
#   dtype: object},
#  {'country': 'Ireland',
#   'ISO_A3': 'IRL',
#   'name': 'Ireland',
#   'geometry': 0    (POLYGON ((-7.218652343749982 55.0919921875, -...
#   dtype: object},
#  {'country': 'Iraq',
#   'ISO_A3': 'IRQ',
#   'name': 'Iraq',
#   'geometry': 0    POLYGON ((42.35898437500001 37.10859374999999,...
#   dtype: object},
#  {'country': 'Iran',
#   'ISO_A3': 'IRN',
#   'name': 'Iran',
#   'geometry': 0    (POLYGON ((56.18798828124999 26.92114257812498...
#   dtype: object},
#  {'country': 'Indonesia',
#   'ISO_A3': 'IDN',
#   'name': 'Indonesia',
#   'geometry': 0    (POLYGON ((122.94892578125 -10.90927734375002,...
#   dtype: object},
#  {'country': 'India',
#   'ISO_A3': 'IND',
#   'name': 'India',
#   'geometry': 0    (POLYGON ((93.89003906249998 6.831054687500008...
#   dtype: object},
#  {'country': 'Iceland',
#   'ISO_A3': 'ISL',
#   'name': 'Iceland',
#   'geometry': 0    POLYGON ((-15.54311523437498 66.228515625, -15...
#   dtype: object},
#  {'country': 'Hungary',
#   'ISO_A3': 'HUN',
#   'name': 'Hungary',
#   'geometry': 0    POLYGON ((22.13183593749999 48.40532226562499,...
#   dtype: object},
#  {'country': 'Honduras',
#   'ISO_A3': 'HND',
#   'name': 'Honduras',
#   'geometry': 0    (POLYGON ((-83.15751953124999 14.9930664062499...
#   dtype: object},
#  {'country': 'Haiti',
#   'ISO_A3': 'HTI',
#   'name': 'Haiti',
#   'geometry': 0    (POLYGON ((-72.66406249999999 20.0375, -72.623...
#   dtype: object},
#  {'country': 'Guyana',
#   'ISO_A3': 'GUY',
#   'name': 'Guyana',
#   'geometry': 0    POLYGON ((-60.742138671875 5.202050781250014, ...
#   dtype: object},
#  {'country': 'Guinea-Bissau',
#   'ISO_A3': 'GNB',
#   'name': 'Guinea-Bissau',
#   'geometry': 0    (POLYGON ((-15.98642578124999 11.8820312499999...
#   dtype: object},
#  {'country': 'Guinea',
#   'ISO_A3': 'GIN',
#   'name': 'Guinea',
#   'geometry': 0    POLYGON ((-10.28320312499999 8.485156249999992...
#   dtype: object},
#  {'country': 'Guatemala',
#   'ISO_A3': 'GTM',
#   'name': 'Guatemala',
#   'geometry': 0    POLYGON ((-92.23515624999999 14.54541015624999...
#   dtype: object},
#  {'country': 'Grenada',
#   'ISO_A3': 'GRD',
#   'name': 'Grenada',
#   'geometry': 0    POLYGON ((-61.71552734374998 12.012646484375, ...
#   dtype: object},
#  {'country': 'Greece',
#   'ISO_A3': 'GRC',
#   'name': 'Greece',
#   'geometry': 0    (POLYGON ((23.85224609375 35.53544921875, 23.9...
#   dtype: object},
#  {'country': 'Ghana',
#   'ISO_A3': 'GHA',
#   'name': 'Ghana',
#   'geometry': 0    POLYGON ((-0.06860351562498455 11.115624999999...
#   dtype: object},
#  {'country': 'Germany',
#   'ISO_A3': 'DEU',
#   'name': 'Germany',
#   'geometry': 0    (POLYGON ((14.21142578124998 53.95034179687499...
#   dtype: object},
#  {'country': 'Georgia',
#   'ISO_A3': 'GEO',
#   'name': 'Georgia',
#   'geometry': 0    POLYGON ((43.43945312499997 41.10712890625001,...
#   dtype: object},
#  {'country': 'Gambia',
#   'ISO_A3': 'GMB',
#   'name': 'Gambia',
#   'geometry': 0    POLYGON ((-16.5623046875 13.5873046875, -16.30...
#   dtype: object},
#  {'country': 'Gabon',
#   'ISO_A3': 'GAB',
#   'name': 'Gabon',
#   'geometry': 0    POLYGON ((13.29355468750001 2.161572265625002,...
#   dtype: object},
#  {'country': 'France',
#   'ISO_A3': '-99',
#   'name': 'France',
#   'geometry': 0    (POLYGON ((9.480371093750028 42.80541992187499...
#   dtype: object},
#  {'country': 'France',
#   'ISO_A3': '-99',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((-54.61625976562499 2.326757812499993...
#   dtype: object},
#  {'country': 'France',
#   'ISO_A3': '-99',
#   'name': 'Unknown 1',
#   'geometry': 0    POLYGON ((55.79736328125001 -21.33935546874999...
#   dtype: object},
#  {'country': 'France',
#   'ISO_A3': '-99',
#   'name': 'Unknown 2',
#   'geometry': 0    (POLYGON ((-60.82626953125 14.49448242187499, ...
#   dtype: object},
#  {'country': 'France',
#   'ISO_A3': '-99',
#   'name': 'Unknown 3',
#   'geometry': 0    POLYGON ((45.18027343750001 -12.97675781250001...
#   dtype: object},
#  {'country': 'Saint Pierre and Miquelon',
#   'ISO_A3': 'SPM',
#   'name': 'Saint Pierre and Miquelon',
#   'geometry': 0    (POLYGON ((-56.15073242187501 46.7624023437499...
#   dtype: object},
#  {'country': 'Wallis and Futuna',
#   'ISO_A3': 'WLF',
#   'name': 'Wallis and Futuna',
#   'geometry': 0    (POLYGON ((-178.0466796875 -14.31835937500002,...
#   dtype: object},
#  {'country': 'Saint Martin',
#   'ISO_A3': 'MAF',
#   'name': 'Saint Martin',
#   'geometry': 0    POLYGON ((-63.01118164062498 18.0689453125, -6...
#   dtype: object},
#  {'country': 'Saint Barthelemy',
#   'ISO_A3': 'BLM',
#   'name': 'Saint Barthelemy',
#   'geometry': 0    POLYGON ((-62.83193359375002 17.87646484375001...
#   dtype: object},
#  {'country': 'French Polynesia',
#   'ISO_A3': 'PYF',
#   'name': 'French Polynesia',
#   'geometry': 0    (POLYGON ((-138.505859375 -20.8572265625, -138...
#   dtype: object},
#  {'country': 'French Polynesia',
#   'ISO_A3': 'PYF',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((-138.651123046875 -10.5153320312500...
#   dtype: object},
#  {'country': 'New Caledonia',
#   'ISO_A3': 'NCL',
#   'name': 'New Caledonia',
#   'geometry': 0    (POLYGON ((167.54443359375 -22.62324218750001,...
#   dtype: object},
#  {'country': 'French Southern and Antarctic Lands',
#   'ISO_A3': 'ATF',
#   'name': 'French Southern and Antarctic Lands',
#   'geometry': 0    (POLYGON ((69.18486328125002 -49.1095703125000...
#   dtype: object},
#  {'country': 'French Southern and Antarctic Lands',
#   'ISO_A3': 'ATF',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((51.83457031250001 -46.43994140625001...
#   dtype: object},
#  {'country': 'Aland',
#   'ISO_A3': 'ALA',
#   'name': 'Aland',
#   'geometry': 0    (POLYGON ((20.61132812499999 60.040673828125, ...
#   dtype: object},
#  {'country': 'Finland',
#   'ISO_A3': 'FIN',
#   'name': 'Finland',
#   'geometry': 0    (POLYGON ((24.84824218750001 64.991015625, 24....
#   dtype: object},
#  {'country': 'Fiji',
#   'ISO_A3': 'FJI',
#   'name': 'Fiji',
#   'geometry': 0    (POLYGON ((174.6296875 -21.69501953125001, 174...
#   dtype: object},
#  {'country': 'Fiji',
#   'ISO_A3': 'FJI',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((-178.71162109375 -20.6677734375, -1...
#   dtype: object},
#  {'country': 'Ethiopia',
#   'ISO_A3': 'ETH',
#   'name': 'Ethiopia',
#   'geometry': 0    POLYGON ((35.26835937500001 5.492285156249981,...
#   dtype: object},
#  {'country': 'Estonia',
#   'ISO_A3': 'EST',
#   'name': 'Estonia',
#   'geometry': 0    (POLYGON ((27.35195312500002 57.528125, 27.326...
#   dtype: object},
#  {'country': 'Eritrea',
#   'ISO_A3': 'ERI',
#   'name': 'Eritrea',
#   'geometry': 0    (POLYGON ((36.52431640625002 14.25683593750001...
#   dtype: object},
#  {'country': 'Equatorial Guinea',
#   'ISO_A3': 'GNQ',
#   'name': 'Equatorial Guinea',
#   'geometry': 0    (POLYGON ((11.3287109375 2.167431640624989, 11...
#   dtype: object},
#  {'country': 'El Salvador',
#   'ISO_A3': 'SLV',
#   'name': 'El Salvador',
#   'geometry': 0    POLYGON ((-89.36259765624999 14.41601562500001...
#   dtype: object},
#  {'country': 'Egypt',
#   'ISO_A3': 'EGY',
#   'name': 'Egypt',
#   'geometry': 0    POLYGON ((36.87138671875 21.99672851562498, 36...
#   dtype: object},
#  {'country': 'Ecuador',
#   'ISO_A3': 'ECU',
#   'name': 'Ecuador',
#   'geometry': 0    (POLYGON ((-78.90922851562499 1.25278320312498...
#   dtype: object},
#  {'country': 'Ecuador',
#   'ISO_A3': 'ECU',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((-90.42392578124998 -1.3399414062500...
#   dtype: object},
#  {'country': 'Dominican Republic',
#   'ISO_A3': 'DOM',
#   'name': 'Dominican Republic',
#   'geometry': 0    POLYGON ((-71.768310546875 18.03916015625001, ...
#   dtype: object},
#  {'country': 'Dominica',
#   'ISO_A3': 'DMA',
#   'name': 'Dominica',
#   'geometry': 0    POLYGON ((-61.281689453125 15.24902343750001, ...
#   dtype: object},
#  {'country': 'Djibouti',
#   'ISO_A3': 'DJI',
#   'name': 'Djibouti',
#   'geometry': 0    POLYGON ((43.24599609375001 11.49980468749996,...
#   dtype: object},
#  {'country': 'Greenland',
#   'ISO_A3': 'GRL',
#   'name': 'Greenland',
#   'geometry': 0    (POLYGON ((-18.00053710937499 75.4073242187499...
#   dtype: object},
#  {'country': 'Faroe Islands',
#   'ISO_A3': 'FRO',
#   'name': 'Faroe Islands',
#   'geometry': 0    (POLYGON ((-6.699462890624989 61.4446289062499...
#   dtype: object},
#  {'country': 'Denmark',
#   'ISO_A3': 'DNK',
#   'name': 'Denmark',
#   'geometry': 0    (POLYGON ((15.08769531250003 55.02187499999998...
#   dtype: object},
#  {'country': 'Czechia',
#   'ISO_A3': 'CZE',
#   'name': 'Czechia',
#   'geometry': 0    POLYGON ((18.83222656250002 49.510791015625, 1...
#   dtype: object},
#  {'country': 'Northern Cyprus',
#   'ISO_A3': '-99',
#   'name': 'Northern Cyprus',
#   'geometry': 0    POLYGON ((34.00449218750002 35.065234375, 33.9...
#   dtype: object},
#  {'country': 'Cyprus',
#   'ISO_A3': 'CYP',
#   'name': 'Cyprus',
#   'geometry': 0    POLYGON ((32.7126953125 35.171044921875, 32.72...
#   dtype: object},
#  {'country': 'Cuba',
#   'ISO_A3': 'CUB',
#   'name': 'Cuba',
#   'geometry': 0    (POLYGON ((-82.561767578125 21.57167968749998,...
#   dtype: object},
#  {'country': 'Croatia',
#   'ISO_A3': 'HRV',
#   'name': 'Croatia',
#   'geometry': 0    (POLYGON ((17.60781250000002 42.76904296874999...
#   dtype: object},
#  {'country': 'Ivory Coast',
#   'ISO_A3': 'CIV',
#   'name': 'Ivory Coast',
#   'geometry': 0    (POLYGON ((-3.086718749999992 5.12832031249999...
#   dtype: object},
#  {'country': 'Costa Rica',
#   'ISO_A3': 'CRI',
#   'name': 'Costa Rica',
#   'geometry': 0    POLYGON ((-82.56357421874999 9.576660156250009...
#   dtype: object},
#  {'country': 'Democratic Republic of the Congo',
#   'ISO_A3': 'COD',
#   'name': 'Democratic Republic of the Congo',
#   'geometry': 0    POLYGON ((30.75117187500002 -8.193652343749999...
#   dtype: object},
#  {'country': 'Republic of the Congo',
#   'ISO_A3': 'COG',
#   'name': 'Republic of the Congo',
#   'geometry': 0    POLYGON ((11.13017578125002 -3.916308593750005...
#   dtype: object},
#  {'country': 'Comoros',
#   'ISO_A3': 'COM',
#   'name': 'Comoros',
#   'geometry': 0    (POLYGON ((44.47636718750002 -12.0815429687500...
#   dtype: object},
#  {'country': 'Colombia',
#   'ISO_A3': 'COL',
#   'name': 'Colombia',
#   'geometry': 0    (POLYGON ((-78.113720703125 2.541748046874989,...
#   dtype: object},
#  {'country': 'China',
#   'ISO_A3': 'CHN',
#   'name': 'China',
#   'geometry': 0    (POLYGON ((110.88876953125 19.99194335937498, ...
#   dtype: object},
#  {'country': 'Macao S.A.R',
#   'ISO_A3': 'MAC',
#   'name': 'Macao S.A.R',
#   'geometry': 0    POLYGON ((113.4789062500001 22.195556640625, 1...
#   dtype: object},
#  {'country': 'Hong Kong S.A.R.',
#   'ISO_A3': 'HKG',
#   'name': 'Hong Kong S.A.R.',
#   'geometry': 0    (POLYGON ((113.99775390625 22.21049804687501, ...
#   dtype: object},
#  {'country': 'Chile',
#   'ISO_A3': 'CHL',
#   'name': 'Chile',
#   'geometry': 0    (POLYGON ((-67.57519531249999 -55.8896484375, ...
#   dtype: object},
#  {'country': 'Chile',
#   'ISO_A3': 'CHL',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((-109.27998046875 -27.14042968750002,...
#   dtype: object},
#  {'country': 'Chad',
#   'ISO_A3': 'TCD',
#   'name': 'Chad',
#   'geometry': 0    POLYGON ((23.98027343750002 19.49663085937499,...
#   dtype: object},
#  {'country': 'Central African Republic',
#   'ISO_A3': 'CAF',
#   'name': 'Central African Republic',
#   'geometry': 0    POLYGON ((24.14736328125002 8.665625, 24.19482...
#   dtype: object},
#  {'country': 'Cabo Verde',
#   'ISO_A3': 'CPV',
#   'name': 'Cabo Verde',
#   'geometry': 0    (POLYGON ((-24.30825195312499 14.8562988281249...
#   dtype: object},
#  {'country': 'Canada',
#   'ISO_A3': 'CAN',
#   'name': 'Canada',
#   'geometry': 0    (POLYGON ((-54.55439453125 49.58886718750001, ...
#   dtype: object},
#  {'country': 'Cameroon',
#   'ISO_A3': 'CMR',
#   'name': 'Cameroon',
#   'geometry': 0    POLYGON ((8.55585937500001 4.755224609374978, ...
#   dtype: object},
#  {'country': 'Cambodia',
#   'ISO_A3': 'KHM',
#   'name': 'Cambodia',
#   'geometry': 0    (POLYGON ((103.0451171875 11.28505859375, 103....
#   dtype: object},
#  {'country': 'Myanmar',
#   'ISO_A3': 'MMR',
#   'name': 'Myanmar',
#   'geometry': 0    (POLYGON ((93.49179687500006 19.89257812499998...
#   dtype: object},
#  {'country': 'Burundi',
#   'ISO_A3': 'BDI',
#   'name': 'Burundi',
#   'geometry': 0    POLYGON ((30.55361328125001 -2.40009765625001,...
#   dtype: object},
#  {'country': 'Burkina Faso',
#   'ISO_A3': 'BFA',
#   'name': 'Burkina Faso',
#   'geometry': 0    POLYGON ((0.900488281250019 10.99326171875, 0....
#   dtype: object},
#  {'country': 'Bulgaria',
#   'ISO_A3': 'BGR',
#   'name': 'Bulgaria',
#   'geometry': 0    POLYGON ((28.01445312500003 41.96904296874999,...
#   dtype: object},
#  {'country': 'Brunei',
#   'ISO_A3': 'BRN',
#   'name': 'Brunei',
#   'geometry': 0    (POLYGON ((115.0267578125 4.899707031249988, 1...
#   dtype: object},
#  {'country': 'Brazil',
#   'ISO_A3': 'BRA',
#   'name': 'Brazil',
#   'geometry': 0    (POLYGON ((-38.90356445312502 -13.473437500000...
#   dtype: object},
#  {'country': 'Botswana',
#   'ISO_A3': 'BWA',
#   'name': 'Botswana',
#   'geometry': 0    POLYGON ((25.25878906249999 -17.7935546875, 25...
#   dtype: object},
#  {'country': 'Bosnia and Herzegovina',
#   'ISO_A3': 'BIH',
#   'name': 'Bosnia and Herzegovina',
#   'geometry': 0    POLYGON ((19.34863281249999 44.88090820312497,...
#   dtype: object},
#  {'country': 'Bolivia',
#   'ISO_A3': 'BOL',
#   'name': 'Bolivia',
#   'geometry': 0    POLYGON ((-69.5109375 -17.50605468750002, -69....
#   dtype: object},
#  {'country': 'Bhutan',
#   'ISO_A3': 'BTN',
#   'name': 'Bhutan',
#   'geometry': 0    POLYGON ((91.63193359375005 27.75996093749998,...
#   dtype: object},
#  {'country': 'Benin',
#   'ISO_A3': 'BEN',
#   'name': 'Benin',
#   'geometry': 0    POLYGON ((1.62265625 6.216796875000015, 1.6109...
#   dtype: object},
#  {'country': 'Belize',
#   'ISO_A3': 'BLZ',
#   'name': 'Belize',
#   'geometry': 0    (POLYGON ((-89.16147460937499 17.81484375, -89...
#   dtype: object},
#  {'country': 'Belgium',
#   'ISO_A3': 'BEL',
#   'name': 'Belgium',
#   'geometry': 0    POLYGON ((4.226171875000008 51.38647460937499,...
#   dtype: object},
#  {'country': 'Belarus',
#   'ISO_A3': 'BLR',
#   'name': 'Belarus',
#   'geometry': 0    POLYGON ((31.76337890625 52.10107421874999, 31...
#   dtype: object},
#  {'country': 'Barbados',
#   'ISO_A3': 'BRB',
#   'name': 'Barbados',
#   'geometry': 0    POLYGON ((-59.49331054687499 13.081982421875, ...
#   dtype: object},
#  {'country': 'Bangladesh',
#   'ISO_A3': 'BGD',
#   'name': 'Bangladesh',
#   'geometry': 0    (POLYGON ((90.64179687499998 22.96298828124997...
#   dtype: object},
#  {'country': 'Bahrain',
#   'ISO_A3': 'BHR',
#   'name': 'Bahrain',
#   'geometry': 0    POLYGON ((50.60722656250002 25.88310546874999,...
#   dtype: object},
#  {'country': 'The Bahamas',
#   'ISO_A3': 'BHS',
#   'name': 'The Bahamas',
#   'geometry': 0    (POLYGON ((-73.02685546874999 21.1923828124999...
#   dtype: object},
#  {'country': 'Azerbaijan',
#   'ISO_A3': 'AZE',
#   'name': 'Azerbaijan',
#   'geometry': 0    (POLYGON ((45.0236328125 41.02724609374999, 45...
#   dtype: object},
#  {'country': 'Austria',
#   'ISO_A3': 'AUT',
#   'name': 'Austria',
#   'geometry': 0    POLYGON ((9.527539062499997 47.27075195312499,...
#   dtype: object},
#  {'country': 'Australia',
#   'ISO_A3': 'AUS',
#   'name': 'Australia',
#   'geometry': 0    (POLYGON ((148.104296875 -42.71044921875001, 1...
#   dtype: object},
#  {'country': 'Australia',
#   'ISO_A3': 'AUS',
#   'name': 'Unknown 0',
#   'geometry': 0    POLYGON ((158.87880859375 -54.70976562500002, ...
#   dtype: object},
#  {'country': 'Indian Ocean Territories',
#   'ISO_A3': '-99',
#   'name': 'Indian Ocean Territories',
#   'geometry': 0    POLYGON ((105.725390625 -10.49296875000001, 10...
#   dtype: object},
#  {'country': 'Indian Ocean Territories',
#   'ISO_A3': '-99',
#   'name': 'Unknown 0',
#   'geometry': 0    (POLYGON ((96.91826171875 -12.19414062500002, ...
#   dtype: object},
#  {'country': 'Heard Island and McDonald Islands',
#   'ISO_A3': 'HMD',
#   'name': 'Heard Island and McDonald Islands',
#   'geometry': 0    POLYGON ((73.70742187500001 -53.13710937499999...
#   dtype: object},
#  {'country': 'Norfolk Island',
#   'ISO_A3': 'NFK',
#   'name': 'Norfolk Island',
#   'geometry': 0    POLYGON ((167.939453125 -29.01767578125002, 16...
#   dtype: object},
#  {'country': 'Ashmore and Cartier Islands',
#   'ISO_A3': '-99',
#   'name': 'Ashmore and Cartier Islands',
#   'geometry': 0    POLYGON ((123.59453125 -12.42568359375002, 123...
#   dtype: object},
#  {'country': 'Armenia',
#   'ISO_A3': 'ARM',
#   'name': 'Armenia',
#   'geometry': 0    (POLYGON ((44.76826171875 39.70351562499998, 4...
#   dtype: object},
#  {'country': 'Argentina',
#   'ISO_A3': 'ARG',
#   'name': 'Argentina',
#   'geometry': 0    (POLYGON ((-64.54916992187499 -54.716210937499...
#   dtype: object},
#  {'country': 'Antigua and Barbuda',
#   'ISO_A3': 'ATG',
#   'name': 'Antigua and Barbuda',
#   'geometry': 0    (POLYGON ((-61.71606445312501 17.0370117187499...
#   dtype: object},
#  {'country': 'Angola',
#   'ISO_A3': 'AGO',
#   'name': 'Angola',
#   'geometry': 0    (POLYGON ((23.96650390625 -10.87177734375, 23....
#   dtype: object},
#  {'country': 'Andorra',
#   'ISO_A3': 'AND',
#   'name': 'Andorra',
#   'geometry': 0    POLYGON ((1.70605468749999 42.50332031249997, ...
#   dtype: object},
#  {'country': 'Algeria',
#   'ISO_A3': 'DZA',
#   'name': 'Algeria',
#   'geometry': 0    POLYGON ((8.576562500000019 36.93720703125, 8....
#   dtype: object},
#  {'country': 'Albania',
#   'ISO_A3': 'ALB',
#   'name': 'Albania',
#   'geometry': 0    POLYGON ((19.34238281250001 41.86909179687498,...
#   dtype: object},
#  {'country': 'Afghanistan',
#   'ISO_A3': 'AFG',
#   'name': 'Afghanistan',
#   'geometry': 0    POLYGON ((66.522265625 37.34848632812498, 66.8...
#   dtype: object},
#  {'country': 'Siachen Glacier',
#   'ISO_A3': '-99',
#   'name': 'Siachen Glacier',
#   'geometry': 0    POLYGON ((77.04863281249995 35.10991210937499,...
#   dtype: object},
#  {'country': 'Antarctica',
#   'ISO_A3': 'ATA',
#   'name': 'Antarctica',
#   'geometry': 0    (POLYGON ((-161.993798828125 -83.1187500000000...
#   dtype: object},
#  {'country': 'Sint Maarten',
#   'ISO_A3': 'SXM',
#   'name': 'Sint Maarten',
#   'geometry': 0    POLYGON ((-63.12304687499997 18.0689453125, -6...
#   dtype: object}]

# %%
country_list = []
dissolve_buffer_m_step1 = 1000000
dissolve_buffer_m_step2 = 2000000
# 0. Read countries and project to EPSG 3857 (pseudomercator).
# Project layer to EPSG 3857, because shapely only supports buffer calculations on cartesian plane.
all_countries_3857 = all_countries_4326.to_crs(epsg=3857)
# 1. Iterate over all countries, and perform the following...
for index, country in all_countries_3857.iterrows():
    print(f'Processing: {country["ADMIN"]} ({country["ISO_A3"]})')
    geometry_groups = []
    geoseries = []
    if country.geometry.geom_type == 'Polygon':
        # Process single polygon
        # 7. If the country consists of a single polygon, skip steps 3-6 and directly add it to the geometry list.
        geometry_groups.append(country.geometry)
    else:
        # Process multipolygon
        # 2. Split the country geometry into single polygons.
        country_parts = gpd.GeoDataFrame({'geometry': country.geometry}, crs=all_countries_3857.crs)
        while country_parts.shape[0] > 0:
            # 3. Pass 1: Find largest polygon, create a buffer around it and use the resulting bounding box to find all polygons that have their centroid within and merge all of them into a multipolygon.
            primary_step1 = country_parts[country_parts.area == country_parts.area.max()]
            primary_buffered_bbox_step1 = primary_step1.buffer(distance=dissolve_buffer_m_step1).envelope.iloc[0]
            within_primary_bool_step1 = country_parts.centroid.within(primary_buffered_bbox_step1)
            merged_primary_step1 = country_parts.loc[within_primary_bool_step1].unary_union
            if country_parts.shape[0] == 0:
                # If no more geometries are left, add primary from step 1 and break.
                geometry_groups.append(merged_primary_step1)
                break
            # 4. Pass 2: Using the resulting geometry of step 3, create a larger buffer and again find all polygons with their centroid within the resulting bounding box and merge them.
            primary_buffered_bbox_step2 = merged_primary_step1.buffer(distance=dissolve_buffer_m_step2).envelope
            within_primary_bool_step2 = country_parts.centroid.within(primary_buffered_bbox_step2)
            merged_primary_step2 = country_parts.loc[within_primary_bool_step2].unary_union
            # 5. Remove the resulting multipolygon from the two passes from the dataset and add it to a geometry list.
            country_parts = country_parts.loc[within_primary_bool_step2 == False]
            # APPEND PRIMARY FOUND IN PASS 2
            geometry_groups.append(merged_primary_step2)
            # 6. If there still are polygons left, go to step 3.

    # 8. Convert the resulting geometries from the geometry list back to EPSG 4326 and add them to the result list.
    # Create a list of country parts that allows easy navigation for subsequent name entering. Assume largest Polygon is has country name as title.
    geometry_groups = [gpd.GeoSeries(geom, crs=3857).to_crs(epsg=4326).geometry for geom in geometry_groups]
    country_list.append({
        'country': country['ADMIN'],
        'ISO_A3': country['ISO_A3'],
        'name': country['ADMIN'],
        'geometry': geometry_groups.pop(0),
    })
    for i, geometry in enumerate(geometry_groups):
        country_list.append({
            'country': country['ADMIN'],
            'ISO_A3': country['ISO_A3'],
            'name': f'Unknown {i}',
            'geometry': geometry
        })
