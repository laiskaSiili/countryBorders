# %% [markdown]
# # Map styling

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pickle

# %%
country_dict = pickle.load(open('country_dict.p', 'rb'))

# %%
# This function draws the country with a given ISO code
def draw_country(iso_code):
    fig = plt.figure(figsize=(9.8, 5.25), frameon=True, facecolor="#f0f0ed")
    global country_dict
    rows = country_dict[iso_code]['rows']
    cols = country_dict[iso_code]['cols']
    for i, p in enumerate(country_dict[iso_code]['parts']):
        ax = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(p['rowroot'], p['colroot']),
            colspan=p['colspan'],
            rowspan=p['rowspan'],
        )
        if iso_code == "KIR":
            edgecolor = "black"
        else:
            edgecolor = None
        p['geometry'].plot(ax=ax, facecolor='#c7c7c4', edgecolor=edgecolor)
        plt.axis('equal')
        if i > 0 or iso_code == "KIR":
            plt.xlabel(p['name'], fontsize=11, labelpad=0)
            ax.xaxis.set_major_formatter(NullFormatter())
            ax.xaxis.set_ticks_position('none')
            ax.yaxis.set_major_formatter(NullFormatter())
            ax.yaxis.set_ticks_position('none')
        else:
            ax.set_axis_off()
        ax.set_facecolor("#f0f0ed")
    if iso_code == "KIR":
        ax_top = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(0, 0),
            colspan=3,
            rowspan=1,
        )
        ax_bottom = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(4, 0),
            colspan=3,
            rowspan=1,
        )
        ax_top.set_axis_off()
        ax_bottom.set_axis_off()
    fig.tight_layout()
    plt.subplots_adjust(hspace=0.5)
    plt.savefig('foo.png', facecolor="#f0f0ed", bbox_inches='tight', pad_inches=0.3);

# %%
draw_country('JPN')

# %%
country_dict['USA']

# %% [markdown]
# ### Serializing the data

# %%
import json
import pickle
from shapely.geometry import mapping

# %%
country_dict = pickle.load(open('country_dict.p', 'rb'))

# %%
serialized_country_dict = country_dict.copy()
for country_code in serialized_country_dict:
    serialized_country_dict[country_code]['parts'] = [{key: val if key != 'geometry' else mapping(val)["features"][0]["geometry"] for key, val in part.items()}for part in serialized_country_dict[country_code]['parts']]

# %%
json.dump(serialized_country_dict, open('country.json', 'w'))

# %% [markdown]
# ### De-serializing the data

# %%
import json
import geopandas as gpd
from shapely.geometry import shape

# %%
serialized_country_dict = json.loads(open('country.json').read())

# %%
serialized_country_dict = json.loads(open('country.json').read())
country_dict = serialized_country_dict["USA"]
json.dump(country_dict, open('usa.json', 'w'))

# %%
deserialized_country_dict = serialized_country_dict.copy()
for country_code in deserialized_country_dict:
    deserialized_country_dict[country_code]['parts'] = [{key: val if key != 'geometry' else gpd.GeoSeries(shape(val).buffer(0), crs=4326) for key, val in part.items()} for part in deserialized_country_dict[country_code]['parts']]

# %%
deserialized_country_dict
# Out:
# {'AFG': {'name': 'Afghanistan',
#   'ISO': 'AFG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Afghanistan',
#     'main': True,
#     'geometry': 0    POLYGON ((74.54235396300002 37.02166900600012,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ALB': {'name': 'Albania',
#   'ISO': 'ALB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Albania',
#     'main': True,
#     'geometry': 0    POLYGON ((20.56714725800009 41.87318166200001,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'DZA': {'name': 'Algeria',
#   'ISO': 'DZA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Algeria',
#     'main': True,
#     'geometry': 0    POLYGON ((-4.821613117999902 24.99506459600007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'AND': {'name': 'Andorra',
#   'ISO': 'AND',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Andorra',
#     'main': True,
#     'geometry': 0    POLYGON ((1.707006470000067 42.50278147400006,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'AGO': {'name': 'Angola',
#   'ISO': 'AGO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Angola',
#     'main': True,
#     'geometry': 0    (POLYGON ((23.96745650200009 -10.8723068229999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ATG': {'name': 'Antigua and Barbuda',
#   'ISO': 'ATG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Antigua and Barbuda',
#     'main': True,
#     'geometry': 0    (POLYGON ((-61.88361568899996 17.0490176450000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ARG': {'name': 'Argentina',
#   'ISO': 'ARG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Argentina',
#     'main': True,
#     'geometry': 0    (POLYGON ((-67.2847505553385 -23.8341371224569...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ARM': {'name': 'Armenia',
#   'ISO': 'ARM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Armenia',
#     'main': True,
#     'geometry': 0    (POLYGON ((45.0023999440001 41.29045237300006,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'AUS': {'name': 'Australia',
#   'ISO': 'AUS',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Australia',
#     'main': True,
#     'geometry': 0    (POLYGON ((154.391286655 -21.03004322699991, 1...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'AUT': {'name': 'Austria',
#   'ISO': 'AUT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Austria',
#     'main': True,
#     'geometry': 0    POLYGON ((16.94504276600014 48.60416615800008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'AZE': {'name': 'Azerbaijan',
#   'ISO': 'AZE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Azerbaijan',
#     'main': True,
#     'geometry': 0    (POLYGON ((50.61890709700003 40.29999420800004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BHS': {'name': 'Bahamas',
#   'ISO': 'BHS',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bahamas',
#     'main': True,
#     'geometry': 0    (POLYGON ((-73.13914954299992 22.3633487000000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BHR': {'name': 'Bahrain',
#   'ISO': 'BHR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bahrain',
#     'main': True,
#     'geometry': 0    POLYGON ((50.55160566500007 26.19424062700005,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BGD': {'name': 'Bangladesh',
#   'ISO': 'BGD',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bangladesh',
#     'main': True,
#     'geometry': 0    (POLYGON ((92.57587854000013 21.97757436200001...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BRB': {'name': 'Barbados',
#   'ISO': 'BRB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Barbados',
#     'main': True,
#     'geometry': 0    POLYGON ((-59.42690995999993 13.16038646000004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BLR': {'name': 'Belarus',
#   'ISO': 'BLR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Belarus',
#     'main': True,
#     'geometry': 0    POLYGON ((23.60623824100014 51.517399191, 23.6...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BEL': {'name': 'Belgium',
#   'ISO': 'BEL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Belgium',
#     'main': True,
#     'geometry': 0    POLYGON ((2.521799927545687 51.08754088371881,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BLZ': {'name': 'Belize',
#   'ISO': 'BLZ',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Belize',
#     'main': True,
#     'geometry': 0    (POLYGON ((-87.82774817599993 17.5455589860000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BEN': {'name': 'Benin',
#   'ISO': 'BEN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Benin',
#     'main': True,
#     'geometry': 0    POLYGON ((3.596400187000113 11.69577300999999,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BTN': {'name': 'Bhutan',
#   'ISO': 'BTN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bhutan',
#     'main': True,
#     'geometry': 0    POLYGON ((91.63288700400005 27.759443665, 91.6...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BOL': {'name': 'Bolivia',
#   'ISO': 'BOL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bolivia',
#     'main': True,
#     'geometry': 0    POLYGON ((-69.51008875199994 -17.5065881979999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BIH': {'name': 'Bosnia and Herzegovina',
#   'ISO': 'BIH',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bosnia and Herzegovina',
#     'main': True,
#     'geometry': 0    POLYGON ((17.65333092500009 42.89093659100008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BWA': {'name': 'Botswana',
#   'ISO': 'BWA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Botswana',
#     'main': True,
#     'geometry': 0    POLYGON ((25.25978072100011 -17.79410654699998...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BRA': {'name': 'Brazil',
#   'ISO': 'BRA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Brazil',
#     'main': True,
#     'geometry': 0    (POLYGON ((-28.88329016799992 -20.518731377999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BRN': {'name': 'Brunei',
#   'ISO': 'BRN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Brunei',
#     'main': True,
#     'geometry': 0    (POLYGON ((115.1461694670001 4.908514716000069...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BGR': {'name': 'Bulgaria',
#   'ISO': 'BGR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Bulgaria',
#     'main': True,
#     'geometry': 0    POLYGON ((26.33335860200012 41.71303639700009,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BFA': {'name': 'Burkina Faso',
#   'ISO': 'BFA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Burkina Faso',
#     'main': True,
#     'geometry': 0    POLYGON ((2.390168904000092 11.89653595000004,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'BDI': {'name': 'Burundi',
#   'ISO': 'BDI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Burundi',
#     'main': True,
#     'geometry': 0    POLYGON ((30.55459965000005 -2.400627542999887...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KHM': {'name': 'Cambodia',
#   'ISO': 'KHM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Cambodia',
#     'main': True,
#     'geometry': 0    (POLYGON ((107.5203927000001 14.70458160500001...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CMR': {'name': 'Cameroon',
#   'ISO': 'CMR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Cameroon',
#     'main': True,
#     'geometry': 0    POLYGON ((11.32207849100004 2.165760396000033,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CAN': {'name': 'Canada',
#   'ISO': 'CAN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Canada',
#     'main': True,
#     'geometry': 0    (POLYGON ((-52.62881425699993 47.5266787780000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CPV': {'name': 'Cape Verde',
#   'ISO': 'CPV',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Cape Verde',
#     'main': True,
#     'geometry': 0    (POLYGON ((-22.68211829299992 16.1135928410000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CAF': {'name': 'Central African Republic',
#   'ISO': 'CAF',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Central African Republic',
#     'main': True,
#     'geometry': 0    POLYGON ((22.86106408700007 10.91915374700006,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TCD': {'name': 'Chad',
#   'ISO': 'TCD',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Chad',
#     'main': True,
#     'geometry': 0    POLYGON ((14.0649084880001 13.07798838300005, ...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CHL': {'name': 'Chile',
#   'ISO': 'CHL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Chile',
#     'main': True,
#     'geometry': 0    (POLYGON ((-66.42674719999991 -55.185479424999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CHN': {'name': 'China',
#   'ISO': 'CHN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'China',
#     'main': True,
#     'geometry': 0    (POLYGON ((78.91594777500006 33.3876559810001,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'COL': {'name': 'Colombia',
#   'ISO': 'COL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Colombia',
#     'main': True,
#     'geometry': 0    (POLYGON ((-78.82868404899995 1.43431224200007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'COM': {'name': 'Comoros',
#   'ISO': 'COM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Comoros',
#     'main': True,
#     'geometry': 0    (POLYGON ((44.52906334700003 -12.2328427059999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CRI': {'name': 'Costa Rica',
#   'ISO': 'CRI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Costa Rica',
#     'main': True,
#     'geometry': 0    (POLYGON ((-83.64435787699998 10.9259300800000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'HRV': {'name': 'Croatia',
#   'ISO': 'HRV',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Croatia',
#     'main': True,
#     'geometry': 0    (POLYGON ((16.51530155400008 46.50171051000011...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CUB': {'name': 'Cuba',
#   'ISO': 'CUB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Cuba',
#     'main': True,
#     'geometry': 0    (POLYGON ((-75.0950058107462 19.8972259625988,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CYP': {'name': 'Cyprus',
#   'ISO': 'CYP',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Cyprus',
#     'main': True,
#     'geometry': 0    (POLYGON ((33.7029346110001 34.98794301400002,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CZE': {'name': 'Czech Republic',
#   'ISO': 'CZE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Czech Republic',
#     'main': True,
#     'geometry': 0    POLYGON ((14.81039270000014 50.85844716400008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'COD': {'name': 'DR Congo',
#   'ISO': 'COD',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'DR Congo',
#     'main': True,
#     'geometry': 0    (POLYGON ((18.62638716600009 3.476868998000052...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'DNK': {'name': 'Denmark',
#   'ISO': 'DNK',
#   'nr_parts': 3,
#   'rows': 2,
#   'cols': 3,
#   'parts': [{'name': 'Denmark',
#     'main': True,
#     'geometry': 0    (POLYGON ((15.15137780000009 55.13320547100005...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 2,
#     'colspan': 2},
#    {'name': 'Greenland',
#     'main': False,
#     'geometry': 0    (POLYGON ((-40.87580318899995 65.0965029970000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Faroe Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((-6.321441209999932 62.3080915390000...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'DJI': {'name': 'Djibouti',
#   'ISO': 'DJI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Djibouti',
#     'main': True,
#     'geometry': 0    POLYGON ((43.24073326900009 11.48786041900009,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'DMA': {'name': 'Dominica',
#   'ISO': 'DMA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Dominica',
#     'main': True,
#     'geometry': 0    POLYGON ((-61.36286373599994 15.20180898600004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'DOM': {'name': 'Dominican Republic',
#   'ISO': 'DOM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Dominican Republic',
#     'main': True,
#     'geometry': 0    (POLYGON ((-71.75743567599994 19.7101097680000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ECU': {'name': 'Ecuador',
#   'ISO': 'ECU',
#   'nr_parts': 2,
#   'rows': 3,
#   'cols': 3,
#   'parts': [{'name': 'Ecuador',
#     'main': True,
#     'geometry': 0    (POLYGON ((-78.82868404899995 1.43431224200007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 3,
#     'colspan': 2},
#    {'name': 'Galápagos Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((-89.30809485599991 -0.6856421849999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 2,
#     'colspan': 1}]},
#  'EGY': {'name': 'Egypt',
#   'ISO': 'EGY',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Egypt',
#     'main': True,
#     'geometry': 0    (POLYGON ((34.24835085700004 31.21144895800008...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SLV': {'name': 'El Salvador',
#   'ISO': 'SLV',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'El Salvador',
#     'main': True,
#     'geometry': 0    (POLYGON ((-87.72629342699992 13.1983874370000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GNQ': {'name': 'Equatorial Guinea',
#   'ISO': 'GNQ',
#   'nr_parts': 3,
#   'rows': 2,
#   'cols': 4,
#   'parts': [{'name': 'Equatorial Guinea',
#     'main': True,
#     'geometry': 0    POLYGON ((9.799571159000067 2.341742255000027,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 3,
#     'colspan': 3},
#    {'name': 'Bioko',
#     'main': False,
#     'geometry': 0    POLYGON ((8.922699415000068 3.750718492000078,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Annobón',
#     'main': False,
#     'geometry': 0    POLYGON ((5.626231316000086 -1.45623137799993,...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ERI': {'name': 'Eritrea',
#   'ISO': 'ERI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Eritrea',
#     'main': True,
#     'geometry': 0    (POLYGON ((43.11768639400008 12.70791250200005...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'EST': {'name': 'Estonia',
#   'ISO': 'EST',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Estonia',
#     'main': True,
#     'geometry': 0    (POLYGON ((24.30615873423829 57.86818625584297...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ETH': {'name': 'Ethiopia',
#   'ISO': 'ETH',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Ethiopia',
#     'main': True,
#     'geometry': 0    POLYGON ((34.07069786300013 9.454592111000069,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'FJI': {'name': 'Fiji',
#   'ISO': 'FJI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Fiji',
#     'main': True,
#     'geometry': 0    (POLYGON ((181.7732039720001 -19.8400204409999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'FIN': {'name': 'Finland',
#   'ISO': 'FIN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Finland',
#     'main': True,
#     'geometry': 0    (POLYGON ((28.95407718900008 69.02726064100004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'FRA': {'name': 'France',
#   'ISO': 'FRA',
#   'nr_parts': 4,
#   'rows': 3,
#   'cols': 4,
#   'parts': [{'name': 'France',
#     'main': True,
#     'geometry': 0    (POLYGON ((8.56576582100007 42.20856354400007,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 4,
#     'colspan': 3},
#    {'name': 'French Guiana',
#     'main': False,
#     'geometry': 0    POLYGON ((-54.1115266969999 2.114270443000049,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'New Caledonia',
#     'main': False,
#     'geometry': 0    (POLYGON ((168.137461785 -21.43181731599993, 1...
#     dtype: object,
#     'rowroot': 2,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Reunion Island',
#     'main': False,
#     'geometry': 0    POLYGON ((55.78785241000008 -21.10344817499993...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GAB': {'name': 'Gabon',
#   'ISO': 'GAB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Gabon',
#     'main': True,
#     'geometry': 0    (POLYGON ((13.29456791200008 2.161057841000049...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GMB': {'name': 'Gambia',
#   'ISO': 'GMB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Gambia',
#     'main': True,
#     'geometry': 0    POLYGON ((-16.75365149599992 13.06500885600007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GEO': {'name': 'Georgia',
#   'ISO': 'GEO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Georgia',
#     'main': True,
#     'geometry': 0    POLYGON ((41.55119486300003 42.40645742100008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'DEU': {'name': 'Germany',
#   'ISO': 'DEU',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Germany',
#     'main': True,
#     'geometry': 0    (POLYGON ((13.81572473100007 48.76643015600005...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GHA': {'name': 'Ghana',
#   'ISO': 'GHA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Ghana',
#     'main': True,
#     'geometry': 0    POLYGON ((-0.1661091709999596 11.1349803670001...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GRC': {'name': 'Greece',
#   'ISO': 'GRC',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Greece',
#     'main': True,
#     'geometry': 0    (POLYGON ((28.23975670700008 36.43252187700006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GRD': {'name': 'Grenada',
#   'ISO': 'GRD',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Grenada',
#     'main': True,
#     'geometry': 0    (POLYGON ((-61.42804928299994 12.4546572940000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GTM': {'name': 'Guatemala',
#   'ISO': 'GTM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Guatemala',
#     'main': True,
#     'geometry': 0    POLYGON ((-89.36162084999997 14.41547780400005...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GIN': {'name': 'Guinea',
#   'ISO': 'GIN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Guinea',
#     'main': True,
#     'geometry': 0    POLYGON ((-13.30109615799995 9.041489976000031...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GNB': {'name': 'Guinea-Bissau',
#   'ISO': 'GNB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Guinea-Bissau',
#     'main': True,
#     'geometry': 0    (POLYGON ((-13.72827876799991 12.6733877570000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GUY': {'name': 'Guyana',
#   'ISO': 'GUY',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Guyana',
#     'main': True,
#     'geometry': 0    (POLYGON ((-56.48181901099991 1.94161387100012...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'HTI': {'name': 'Haiti',
#   'ISO': 'HTI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Haiti',
#     'main': True,
#     'geometry': 0    (POLYGON ((-71.75743567599994 19.7101097680000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'HND': {'name': 'Honduras',
#   'ISO': 'HND',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Honduras',
#     'main': True,
#     'geometry': 0    (POLYGON ((-89.36162084999997 14.4154778040000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'HUN': {'name': 'Hungary',
#   'ISO': 'HUN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Hungary',
#     'main': True,
#     'geometry': 0    POLYGON ((22.87760054600005 47.94673858700011,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ISL': {'name': 'Iceland',
#   'ISO': 'ISL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Iceland',
#     'main': True,
#     'geometry': 0    (POLYGON ((-14.56362870999993 66.3845075540000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'IND': {'name': 'India',
#   'ISO': 'IND',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'India',
#     'main': True,
#     'geometry': 0    (POLYGON ((77.80034631400012 35.49540557900011...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'IDN': {'name': 'Indonesia',
#   'ISO': 'IDN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Indonesia',
#     'main': True,
#     'geometry': 0    (POLYGON ((140.974457227 -2.600518487999929, 1...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'IRN': {'name': 'Iran',
#   'ISO': 'IRN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Iran',
#     'main': True,
#     'geometry': 0    (POLYGON ((44.80699282900008 39.63990171200003...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'IRQ': {'name': 'Iraq',
#   'ISO': 'IRQ',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Iraq',
#     'main': True,
#     'geometry': 0    POLYGON ((44.76613529500013 37.14192006500009,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'IRL': {'name': 'Ireland',
#   'ISO': 'IRL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Ireland',
#     'main': True,
#     'geometry': 0    (POLYGON ((-7.247100389999957 55.0693220070000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ISR': {'name': 'Israel',
#   'ISO': 'ISR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Israel',
#     'main': True,
#     'geometry': 0    POLYGON ((34.48120412500009 31.58314132300003,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ITA': {'name': 'Italy',
#   'ISO': 'ITA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Italy',
#     'main': True,
#     'geometry': 0    (POLYGON ((7.022082560000114 45.92525990899998...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CIV': {'name': 'Ivory Coast',
#   'ISO': 'CIV',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Ivory Coast',
#     'main': True,
#     'geometry': 0    (POLYGON ((-7.989662638999988 10.1619906620000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'JAM': {'name': 'Jamaica',
#   'ISO': 'JAM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Jamaica',
#     'main': True,
#     'geometry': 0    POLYGON ((-76.2637426419999 18.01235586100005,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'JPN': {'name': 'Japan',
#   'ISO': 'JPN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Japan',
#     'main': True,
#     'geometry': 0    (POLYGON ((153.972992384 24.28969961100005, 15...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'JOR': {'name': 'Jordan',
#   'ISO': 'JOR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Jordan',
#     'main': True,
#     'geometry': 0    POLYGON ((35.61222375500005 32.68154632600009,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KAZ': {'name': 'Kazakhstan',
#   'ISO': 'KAZ',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Kazakhstan',
#     'main': True,
#     'geometry': 0    (POLYGON ((87.32379602100013 49.08527374300007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KEN': {'name': 'Kenya',
#   'ISO': 'KEN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Kenya',
#     'main': True,
#     'geometry': 0    (POLYGON ((34.38118778500007 4.620158386000087...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KIR': {'name': 'Line Islands',
#   'ISO': 'KIR',
#   'nr_parts': 3,
#   'rows': 5,
#   'cols': 3,
#   'parts': [{'name': 'Line Islands',
#     'main': True,
#     'geometry': 0    (POLYGON ((208.1922713550001 -11.3859188779999...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 2,
#     'rowspan': 3,
#     'colspan': 1},
#    {'name': 'Gilbert Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((176.7861434250001 -2.60816822699991...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 0,
#     'rowspan': 3,
#     'colspan': 1},
#    {'name': 'Phoenix Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((188.9064233730001 -3.13144296699994...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 1,
#     'rowspan': 3,
#     'colspan': 1}]},
#  'XKA': {'name': 'Kosovo',
#   'ISO': 'XKA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Kosovo',
#     'main': True,
#     'geometry': 0    POLYGON ((20.06495568800006 42.54675811800004,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KWT': {'name': 'Kuwait',
#   'ISO': 'KWT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Kuwait',
#     'main': True,
#     'geometry': 0    (POLYGON ((47.94800866000008 29.99404531500002...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KGZ': {'name': 'Kyrgyzstan',
#   'ISO': 'KGZ',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Kyrgyzstan',
#     'main': True,
#     'geometry': 0    POLYGON ((80.21032841000005 42.18951894100005,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LAO': {'name': 'Laos',
#   'ISO': 'LAO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Laos',
#     'main': True,
#     'geometry': 0    POLYGON ((102.1186552330001 22.39754872600002,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LVA': {'name': 'Latvia',
#   'ISO': 'LVA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Latvia',
#     'main': True,
#     'geometry': 0    POLYGON ((27.35293461100013 57.52760081000012,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LBN': {'name': 'Lebanon',
#   'ISO': 'LBN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Lebanon',
#     'main': True,
#     'geometry': 0    POLYGON ((35.10523522200009 33.08901601800008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LSO': {'name': 'Lesotho',
#   'ISO': 'LSO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Lesotho',
#     'main': True,
#     'geometry': 0    POLYGON ((28.98084558100007 -28.909035339, 28....
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LBR': {'name': 'Liberia',
#   'ISO': 'LBR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Liberia',
#     'main': True,
#     'geometry': 0    POLYGON ((-11.47618567599994 6.919419664000077...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LBY': {'name': 'Libya',
#   'ISO': 'LBY',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Libya',
#     'main': True,
#     'geometry': 0    POLYGON ((11.50511180300015 33.18122531500005,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LIE': {'name': 'Liechtenstein',
#   'ISO': 'LIE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Liechtenstein',
#     'main': True,
#     'geometry': 0    POLYGON ((9.52115482500011 47.2628010050001, 9...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LTU': {'name': 'Lithuania',
#   'ISO': 'LTU',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Lithuania',
#     'main': True,
#     'geometry': 0    (POLYGON ((26.59453129100007 55.66699086600005...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LUX': {'name': 'Luxembourg',
#   'ISO': 'LUX',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Luxembourg',
#     'main': True,
#     'geometry': 0    POLYGON ((6.117486613000039 50.12045603500004,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MDG': {'name': 'Madagascar',
#   'ISO': 'MDG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Madagascar',
#     'main': True,
#     'geometry': 0    (POLYGON ((44.25473066500007 -20.3760718729999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MWI': {'name': 'Malawi',
#   'ISO': 'MWI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Malawi',
#     'main': True,
#     'geometry': 0    (POLYGON ((34.96461470600007 -11.5735560099999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MYS': {'name': 'Malaysia',
#   'ISO': 'MYS',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Malaysia',
#     'main': True,
#     'geometry': 0    (POLYGON ((115.1461694670001 4.908514716000069...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MDV': {'name': 'Maldives',
#   'ISO': 'MDV',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Maldives',
#     'main': True,
#     'geometry': 0    (POLYGON ((73.74756920700008 3.451117255000026...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MLI': {'name': 'Mali',
#   'ISO': 'MLI',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Mali',
#     'main': True,
#     'geometry': 0    POLYGON ((-12.2641304119999 14.77493906700003,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MLT': {'name': 'Malta',
#   'ISO': 'MLT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Malta',
#     'main': True,
#     'geometry': 0    (POLYGON ((14.54802493600005 35.89004140800007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MHL': {'name': 'Marshall Islands',
#   'ISO': 'MHL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Marshall Islands',
#     'main': True,
#     'geometry': 0    (POLYGON ((172.0297957690001 6.054144598000046...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MRT': {'name': 'Mauritania',
#   'ISO': 'MRT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Mauritania',
#     'main': True,
#     'geometry': 0    (POLYGON ((-8.68238521299989 27.28541575100011...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MUS': {'name': 'Mauritius',
#   'ISO': 'MUS',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Mauritius',
#     'main': True,
#     'geometry': 0    POLYGON ((57.79574629000007 -20.22275155999995...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MEX': {'name': 'Mexico',
#   'ISO': 'MEX',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Mexico',
#     'main': True,
#     'geometry': 0    (POLYGON ((-86.70059160099991 21.1989199890000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'FSM': {'name': 'Micronesia',
#   'ISO': 'FSM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Micronesia',
#     'main': True,
#     'geometry': 0    (POLYGON ((163.02605228 5.340887762000073, 163...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MDA': {'name': 'Moldova',
#   'ISO': 'MDA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Moldova',
#     'main': True,
#     'geometry': 0    POLYGON ((26.61788903800002 48.25896759100004,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MCO': {'name': 'Monaco',
#   'ISO': 'MCO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Monaco',
#     'main': True,
#     'geometry': 0    POLYGON ((7.437454032126021 43.74336054083464,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MNG': {'name': 'Mongolia',
#   'ISO': 'MNG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Mongolia',
#     'main': True,
#     'geometry': 0    POLYGON ((116.6842777920002 49.82326487300011,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MNE': {'name': 'Montenegro',
#   'ISO': 'MNE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Montenegro',
#     'main': True,
#     'geometry': 0    POLYGON ((18.49642988400007 42.41632721600008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MAR': {'name': 'Morocco',
#   'ISO': 'MAR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Morocco',
#     'main': True,
#     'geometry': 0    POLYGON ((-8.817034779999915 27.66146401100007...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MOZ': {'name': 'Mozambique',
#   'ISO': 'MOZ',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Mozambique',
#     'main': True,
#     'geometry': 0    (POLYGON ((32.11388431800009 -26.8400143429999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MMR': {'name': 'Myanmar',
#   'ISO': 'MMR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Myanmar',
#     'main': True,
#     'geometry': 0    (POLYGON ((92.57587854000013 21.97757436200001...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NAM': {'name': 'Namibia',
#   'ISO': 'NAM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Namibia',
#     'main': True,
#     'geometry': 0    POLYGON ((16.48707116000008 -28.57293059699993...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NRU': {'name': 'Nauru',
#   'ISO': 'NRU',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Nauru',
#     'main': True,
#     'geometry': 0    POLYGON ((166.938812696 -0.4904110659999272, 1...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NPL': {'name': 'Nepal',
#   'ISO': 'NPL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Nepal',
#     'main': True,
#     'geometry': 0    POLYGON ((88.11821781400003 27.86088450100005,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NLD': {'name': 'Netherlands',
#   'ISO': 'NLD',
#   'nr_parts': 3,
#   'rows': 3,
#   'cols': 4,
#   'parts': [{'name': 'Netherlands',
#     'main': True,
#     'geometry': 0    (POLYGON ((7.194590691000087 53.24502187700006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 3,
#     'colspan': 3},
#    {'name': 'Aruba, Curaçao & Bonaire',
#     'main': False,
#     'geometry': 0    (POLYGON ((-68.21153723899994 12.2280947940000...
#     dtype: object,
#     'rowroot': 2,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Sint Maarten, Saba & Sint Eustatius',
#     'main': False,
#     'geometry': 0    (POLYGON ((-62.99714107999993 17.5256208350000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 2,
#     'colspan': 1}]},
#  'NZL': {'name': 'New Zealand',
#   'ISO': 'NZL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'New Zealand',
#     'main': True,
#     'geometry': 0    (POLYGON ((183.8547469410001 -44.2481421849999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NIC': {'name': 'Nicaragua',
#   'ISO': 'NIC',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Nicaragua',
#     'main': True,
#     'geometry': 0    (POLYGON ((-82.7673233709999 14.41412995000006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NER': {'name': 'Niger',
#   'ISO': 'NER',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Niger',
#     'main': True,
#     'geometry': 0    POLYGON ((3.596400187000113 11.69577300999999,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NGA': {'name': 'Nigeria',
#   'ISO': 'NGA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Nigeria',
#     'main': True,
#     'geometry': 0    (POLYGON ((3.596400187000113 11.69577300999999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PRK': {'name': 'North Korea',
#   'ISO': 'PRK',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'North Korea',
#     'main': True,
#     'geometry': 0    (POLYGON ((128.364919467 38.62433502800008, 12...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'MKD': {'name': 'North Macedonia',
#   'ISO': 'MKD',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'North Macedonia',
#     'main': True,
#     'geometry': 0    POLYGON ((20.56714725800009 41.87318166200001,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'NOR': {'name': 'Norway',
#   'ISO': 'NOR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Norway',
#     'main': True,
#     'geometry': 0    (POLYGON ((20.62316451000001 69.0363556930001,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'OMN': {'name': 'Oman',
#   'ISO': 'OMN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Oman',
#     'main': True,
#     'geometry': 0    (POLYGON ((56.38331139400002 24.97821686400003...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PAK': {'name': 'Pakistan',
#   'ISO': 'PAK',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Pakistan',
#     'main': True,
#     'geometry': 0    (POLYGON ((77.04897098800006 35.11044199700002...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PLW': {'name': 'Palau',
#   'ISO': 'PLW',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Palau',
#     'main': True,
#     'geometry': 0    (POLYGON ((134.7096764342737 8.096617828631352...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PAN': {'name': 'Panama',
#   'ISO': 'PAN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Panama',
#     'main': True,
#     'geometry': 0    (POLYGON ((-82.57359778599994 9.57619863500006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PNG': {'name': 'Papua New Guinea',
#   'ISO': 'PNG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Papua New Guinea',
#     'main': True,
#     'geometry': 0    (POLYGON ((155.933441602 -6.640801690999925, 1...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PRY': {'name': 'Paraguay',
#   'ISO': 'PRY',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Paraguay',
#     'main': True,
#     'geometry': 0    POLYGON ((-62.65035721899995 -22.2344556679999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PER': {'name': 'Peru',
#   'ISO': 'PER',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Peru',
#     'main': True,
#     'geometry': 0    (POLYGON ((-69.51008875199994 -17.506588197999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PHL': {'name': 'Philippines',
#   'ISO': 'PHL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Philippines',
#     'main': True,
#     'geometry': 0    (POLYGON ((126.56918379 7.301092841000074, 126...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'POL': {'name': 'Poland',
#   'ISO': 'POL',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Poland',
#     'main': True,
#     'geometry': 0    POLYGON ((18.83319624900008 49.51026072200004,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'PRT': {'name': 'Portugal',
#   'ISO': 'PRT',
#   'nr_parts': 3,
#   'rows': 2,
#   'cols': 4,
#   'parts': [{'name': 'Portugal',
#     'main': True,
#     'geometry': 0    (POLYGON ((-7.270430053999859 38.6176956180000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 2,
#     'rowspan': 2,
#     'colspan': 2},
#    {'name': 'Azores',
#     'main': False,
#     'geometry': 0    (POLYGON ((-25.06680253799993 37.0214704450000...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Madeira',
#     'main': False,
#     'geometry': 0    (POLYGON ((-16.33995520699995 33.0571963560000...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 1,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'QAT': {'name': 'Qatar',
#   'ISO': 'QAT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Qatar',
#     'main': True,
#     'geometry': 0    POLYGON ((50.80787194100009 24.74664948100008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'COG': {'name': 'Republic of the Congo',
#   'ISO': 'COG',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Republic of the Congo',
#     'main': True,
#     'geometry': 0    POLYGON ((18.62638716600009 3.476868998000052,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ROU': {'name': 'Romania',
#   'ISO': 'ROU',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Romania',
#     'main': True,
#     'geometry': 0    POLYGON ((22.87760054600005 47.94673858700011,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'RUS': {'name': 'Russia',
#   'ISO': 'RUS',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Russia',
#     'main': True,
#     'geometry': 0    (POLYGON ((190.9166365890001 65.81586334800004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'RWA': {'name': 'Rwanda',
#   'ISO': 'RWA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Rwanda',
#     'main': True,
#     'geometry': 0    POLYGON ((29.01536543800011 -2.720711364999967...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KNA': {'name': 'Saint Kitts and Nevis',
#   'ISO': 'KNA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Saint Kitts and Nevis',
#     'main': True,
#     'geometry': 0    (POLYGON ((-62.59923255099994 17.2029483090000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LCA': {'name': 'Saint Lucia',
#   'ISO': 'LCA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Saint Lucia',
#     'main': True,
#     'geometry': 0    POLYGON ((-60.88678951699995 14.01007721600006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'VCT': {'name': 'Saint Vincent and the Grenadines',
#   'ISO': 'VCT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Saint Vincent and the Grenadines',
#     'main': True,
#     'geometry': 0    (POLYGON ((-61.16734778599994 13.1460635440000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'WSM': {'name': 'Samoa',
#   'ISO': 'WSM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Samoa',
#     'main': True,
#     'geometry': 0    (POLYGON ((-171.5642797519999 -13.949395440999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SMR': {'name': 'San Marino',
#   'ISO': 'SMR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'San Marino',
#     'main': True,
#     'geometry': 0    POLYGON ((12.4294503590001 43.89205551499999, ...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
# ...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SEN': {'name': 'Senegal',
#   'ISO': 'SEN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Senegal',
#     'main': True,
#     'geometry': 0    POLYGON ((-12.2641304119999 14.77493906700003,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SRB': {'name': 'Serbia',
#   'ISO': 'SRB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Serbia',
#     'main': True,
#     'geometry': 0    POLYGON ((20.24282596900008 46.10809112600005,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SYC': {'name': 'Seychelles',
#   'ISO': 'SYC',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Seychelles',
#     'main': True,
#     'geometry': 0    (POLYGON ((55.94007392970612 -4.57865701180307...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SLE': {'name': 'Sierra Leone',
#   'ISO': 'SLE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Sierra Leone',
#     'main': True,
#     'geometry': 0    (POLYGON ((-10.28223587999989 8.48462534600009...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SGP': {'name': 'Singapore',
#   'ISO': 'SGP',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Singapore',
#     'main': True,
#     'geometry': 0    POLYGON ((103.9607853520001 1.391099351000088,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SVK': {'name': 'Slovakia',
#   'ISO': 'SVK',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Slovakia',
#     'main': True,
#     'geometry': 0    POLYGON ((22.53963667800013 49.07219960600013,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SVN': {'name': 'Slovenia',
#   'ISO': 'SVN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Slovenia',
#     'main': True,
#     'geometry': 0    POLYGON ((13.58952884200005 45.48883698100008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SLB': {'name': 'Solomon Islands',
#   'ISO': 'SLB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Solomon Islands',
#     'main': True,
#     'geometry': 0    (POLYGON ((168.812266472 -12.26628997199992, 1...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SOM': {'name': 'Somalia',
#   'ISO': 'SOM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Somalia',
#     'main': True,
#     'geometry': 0    POLYGON ((46.46696287700007 6.538292406000019,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ZAF': {'name': 'South Africa',
#   'ISO': 'ZAF',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'South Africa',
#     'main': True,
#     'geometry': 0    POLYGON ((19.98144657400005 -24.75249318399993...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'KOR': {'name': 'South Korea',
#   'ISO': 'KOR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'South Korea',
#     'main': True,
#     'geometry': 0    (POLYGON ((131.8610417440001 37.24400618600004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SSD': {'name': 'South Sudan',
#   'ISO': 'SSD',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'South Sudan',
#     'main': True,
#     'geometry': 0    POLYGON ((35.92083540900011 4.619331563000092,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ESP': {'name': 'Spain',
#   'ISO': 'ESP',
#   'nr_parts': 2,
#   'rows': 3,
#   'cols': 4,
#   'parts': [{'name': 'Spain',
#     'main': True,
#     'geometry': 0    (POLYGON ((4.302907748000051 39.92552317900003...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 3,
#     'colspan': 3},
#    {'name': 'Canary Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((-13.48298092399995 29.2399356140000...
#     dtype: object,
#     'rowroot': 2,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'LKA': {'name': 'Sri Lanka',
#   'ISO': 'LKA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Sri Lanka',
#     'main': True,
#     'geometry': 0    (POLYGON ((81.87598717500003 7.091945705000052...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SDN': {'name': 'Sudan',
#   'ISO': 'SDN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Sudan',
#     'main': True,
#     'geometry': 0    (POLYGON ((22.86106408700007 10.91915374700006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SUR': {'name': 'Suriname',
#   'ISO': 'SUR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Suriname',
#     'main': True,
#     'geometry': 0    POLYGON ((-54.08080455699991 3.309314029000075...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SWE': {'name': 'Sweden',
#   'ISO': 'SWE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Sweden',
#     'main': True,
#     'geometry': 0    (POLYGON ((20.62316451000001 69.0363556930001,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'CHE': {'name': 'Switzerland',
#   'ISO': 'CHE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Switzerland',
#     'main': True,
#     'geometry': 0    POLYGON ((10.45381107600014 46.86442738900006,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SYR': {'name': 'Syria',
#   'ISO': 'SYR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Syria',
#     'main': True,
#     'geometry': 0    POLYGON ((35.75759034900011 32.7443468580001, ...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'STP': {'name': 'São Tomé and Príncipe',
#   'ISO': 'STP',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'São Tomé and Príncipe',
#     'main': True,
#     'geometry': 0    (POLYGON ((7.462738477000073 1.674546617000078...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TWN': {'name': 'Taiwan',
#   'ISO': 'TWN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Taiwan',
#     'main': True,
#     'geometry': 0    (POLYGON ((121.9057723320001 24.95010000200004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TJK': {'name': 'Tajikistan',
#   'ISO': 'TJK',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Tajikistan',
#     'main': True,
#     'geometry': 0    (POLYGON ((70.95895511900011 40.23837188800012...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TZA': {'name': 'Tanzania',
#   'ISO': 'TZA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Tanzania',
#     'main': True,
#     'geometry': 0    (POLYGON ((32.9208634850001 -9.407900085999914...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'THA': {'name': 'Thailand',
#   'ISO': 'THA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Thailand',
#     'main': True,
#     'geometry': 0    (POLYGON ((102.913584832 11.64590078300005, 10...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TLS': {'name': 'Timor-Leste',
#   'ISO': 'TLS',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Timor-Leste',
#     'main': True,
#     'geometry': 0    (POLYGON ((124.9195072068366 -8.96201550009757...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TGO': {'name': 'Togo',
#   'ISO': 'TGO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Togo',
#     'main': True,
#     'geometry': 0    POLYGON ((-0.1661091709999596 11.1349803670001...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TON': {'name': 'Tonga',
#   'ISO': 'TON',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Tonga',
#     'main': True,
#     'geometry': 0    (POLYGON ((-173.9563695949999 -18.567315362999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TTO': {'name': 'Trinidad and Tobago',
#   'ISO': 'TTO',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Trinidad and Tobago',
#     'main': True,
#     'geometry': 0    (POLYGON ((-60.53050696499992 11.3510602890000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TUN': {'name': 'Tunisia',
#   'ISO': 'TUN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Tunisia',
#     'main': True,
#     'geometry': 0    (POLYGON ((11.50511180300015 33.18122531500005...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TUR': {'name': 'Turkey',
#   'ISO': 'TUR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Turkey',
#     'main': True,
#     'geometry': 0    (POLYGON ((43.44042810000013 41.10658762600013...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TKM': {'name': 'Turkmenistan',
#   'ISO': 'TKM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Turkmenistan',
#     'main': True,
#     'geometry': 0    (POLYGON ((61.26967574100011 35.61849884000008...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'TUV': {'name': 'Tuvalu',
#   'ISO': 'TUV',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Tuvalu',
#     'main': True,
#     'geometry': 0    (POLYGON ((179.9067488940001 -9.39934661299991...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'UGA': {'name': 'Uganda',
#   'ISO': 'UGA',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Uganda',
#     'main': True,
#     'geometry': 0    POLYGON ((30.47178584300013 -1.06683659199992,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'UKR': {'name': 'Ukraine',
#   'ISO': 'UKR',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Ukraine',
#     'main': True,
#     'geometry': 0    (POLYGON ((31.76434493000005 52.10056772900004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ARE': {'name': 'United Arab Emirates',
#   'ISO': 'ARE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'United Arab Emirates',
#     'main': True,
#     'geometry': 0    (POLYGON ((56.27905523484418 25.62744569785273...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'GBR': {'name': 'United Kingdom',
#   'ISO': 'GBR',
#   'nr_parts': 4,
#   'rows': 3,
#   'cols': 4,
#   'parts': [{'name': 'United Kingdom',
#     'main': True,
#     'geometry': 0    (POLYGON ((-2.665353969999956 51.6172549500000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 1,
#     'rowspan': 3,
#     'colspan': 3},
#    {'name': 'Falkland Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((-57.81623287699993 -51.693536065999...
#     dtype: object,
#     'rowroot': 2,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Cayman Islands',
#     'main': False,
#     'geometry': 0    (POLYGON ((-79.8718891809999 19.70463614000003...
#     dtype: object,
#     'rowroot': 1,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1},
#    {'name': 'Bermuda',
#     'main': False,
#     'geometry': 0    (POLYGON ((-64.67609615799995 32.3886579450000...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'USA': {'name': 'United States',
#   'ISO': 'USA',
#   'nr_parts': 4,
#   'rows': 4,
#   'cols': 5,
#   'parts': [{'name': 'United States',
#     'main': True,
#     'geometry': 0    (POLYGON ((293.0989689460001 44.889390367, 293...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 2,
#     'rowspan': 4,
#     'colspan': 3},
#    {'name': 'Alaska',
#     'main': False,
#     'geometry': 0    (POLYGON ((218.9944360690001 69.65094635600006...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 2,
#     'colspan': 2},
#    {'name': 'Hawaii',
#     'main': False,
#     'geometry': 0    (POLYGON ((205.1003783970001 19.56701629300005...
#     dtype: object,
#     'rowroot': 2,
#     'colroot': 1,
#     'rowspan': 2,
#     'colspan': 1},
#    {'name': 'Puerto Rico & US VI',
#     'main': False,
#     'geometry': 0    (POLYGON ((295.440603061 17.75161367400005, 29...
#     dtype: object,
#     'rowroot': 2,
#     'colroot': 0,
#     'rowspan': 2,
#     'colspan': 1}]},
#  'URY': {'name': 'Uruguay',
#   'ISO': 'URY',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Uruguay',
#     'main': True,
#     'geometry': 0    POLYGON ((-53.37909456943908 -33.7406759723142...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'UZB': {'name': 'Uzbekistan',
#   'ISO': 'UZB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Uzbekistan',
#     'main': True,
#     'geometry': 0    (POLYGON ((70.95895511900011 40.23837188800012...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'VUT': {'name': 'Vanuatu',
#   'ISO': 'VUT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Vanuatu',
#     'main': True,
#     'geometry': 0    (POLYGON ((169.8403426440001 -20.1408016909999...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'VAT': {'name': 'Vatican City',
#   'ISO': 'VAT',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Vatican City',
#     'main': True,
#     'geometry': 0    POLYGON ((12.45313691700008 41.90275194100008,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'VEN': {'name': 'Venezuela',
#   'ISO': 'VEN',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Venezuela',
#     'main': True,
#     'geometry': 0    (POLYGON ((-60.02098548099991 8.55801015800004...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'VNM': {'name': 'Vietnam',
#   'ISO': 'VNM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Vietnam',
#     'main': True,
#     'geometry': 0    (POLYGON ((107.5203927000001 14.70458160500001...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'YEM': {'name': 'Yemen',
#   'ISO': 'YEM',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Yemen',
#     'main': True,
#     'geometry': 0    (POLYGON ((54.47066209000008 12.54356559800003...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ZMB': {'name': 'Zambia',
#   'ISO': 'ZMB',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Zambia',
#     'main': True,
#     'geometry': 0    POLYGON ((32.9208634850001 -9.407900085999914,...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'ZWE': {'name': 'Zimbabwe',
#   'ISO': 'ZWE',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'Zimbabwe',
#     'main': True,
#     'geometry': 0    POLYGON ((25.25978072100011 -17.79410654699998...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]},
#  'SWZ': {'name': 'eSwatini',
#   'ISO': 'SWZ',
#   'nr_parts': 1,
#   'rows': 1,
#   'cols': 1,
#   'parts': [{'name': 'eSwatini',
#     'main': True,
#     'geometry': 0    POLYGON ((31.94924320400008 -25.95810434999991...
#     dtype: object,
#     'rowroot': 0,
#     'colroot': 0,
#     'rowspan': 1,
#     'colspan': 1}]}}

# %% [markdown]
# ### Plotting the map for France

# %%
import geopandas as gpd
from shapely.geometry import shape
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter

# %%
country_dict = json.loads(open('usa.json').read())

# %%
country_dict['parts'] = [{key: val if key != 'geometry' else gpd.GeoSeries(shape(val).buffer(0),
                                                                           crs=4326)
                          for key, val in part.items()} for part in country_dict['parts']]

# %%
fig = plt.figure(figsize=(9.8, 5.25), frameon=True, facecolor="#f0f0ed")
rows = country_dict['rows']
cols = country_dict['cols']
for p in country_dict['parts']:
    ax = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(p['rowroot'], p['colroot']),
            colspan=p['colspan'],
            rowspan=p['rowspan'],
        )
    p['geometry'].plot(ax=ax, facecolor='#c7c7c4', edgecolor=None)
    ax.axis('equal')
    if not p['main']:
        plt.xlabel(p['name'], fontsize=11, labelpad=0)
        ax.xaxis.set_major_formatter(NullFormatter())
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_major_formatter(NullFormatter())
        ax.yaxis.set_ticks_position('none')
    else:
        ax.set_axis_off()
    ax.set_facecolor("#f0f0ed")
plt.subplots_adjust(hspace=0.5)
fig.tight_layout()

# %%
fig = plt.figure(figsize=(9.8, 5.25), frameon=True, facecolor="#f0f0ed")
    global country_dict
    rows = country_dict[iso_code]['rows']
    cols = country_dict[iso_code]['cols']
    for i, p in enumerate(country_dict[iso_code]['parts']):
        ax = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(p['rowroot'], p['colroot']),
            colspan=p['colspan'],
            rowspan=p['rowspan'],
        )
        if iso_code == "KIR":
            edgecolor = "black"
        else:
            edgecolor = None
        p['geometry'].plot(ax=ax, facecolor='#c7c7c4', edgecolor=edgecolor)
        plt.axis('equal')
        if i > 0 or iso_code == "KIR":
            plt.xlabel(p['name'], fontsize=11, labelpad=0)
            ax.xaxis.set_major_formatter(NullFormatter())
            ax.xaxis.set_ticks_position('none')
            ax.yaxis.set_major_formatter(NullFormatter())
            ax.yaxis.set_ticks_position('none')
        else:
            ax.set_axis_off()
        ax.set_facecolor("#f0f0ed")
    if iso_code == "KIR":
        ax_top = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(0, 0),
            colspan=3,
            rowspan=1,
        )
        ax_bottom = plt.subplot2grid(
            shape=(rows, cols), 
            loc=(4, 0),
            colspan=3,
            rowspan=1,
        )
        ax_top.set_axis_off()
        ax_bottom.set_axis_off()
    fig.tight_layout()
    plt.subplots_adjust(hspace=0.5)
    plt.savefig('foo.png', facecolor="#f0f0ed", bbox_inches='tight', pad_inches=0.3);

# %%
fig = plt.figure(figsize=(9.8, 5.25), frameon=True, facecolor="#f0f0ed")
fig.subplot2grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-26260a2c1487> in <module>
#       1 fig = plt.figure(figsize=(9.8, 5.25), frameon=True, facecolor="#f0f0ed")
# ----> 2 fig.subplot2grid()
#
# AttributeError: 'Figure' object has no attribute 'subplot2grid'

# %%
[{key: val for key, val in p.items() if key in set("rowroot", "colroot", "rowspan", "colspan")} for p in country_dict['parts']]
# Out:
# [{'name': 'France',
#   'main': True,
#   'geometry': 0    (POLYGON ((8.56576582100007 42.20856354400007,...
#   dtype: object,
#   'rowroot': 0,
#   'colroot': 1,
#   'rowspan': 4,
#   'colspan': 3},
#  {'name': 'French Guiana',
#   'main': False,
#   'geometry': 0    POLYGON ((-54.1115266969999 2.114270443000049,...
#   dtype: object,
#   'rowroot': 0,
#   'colroot': 0,
#   'rowspan': 1,
#   'colspan': 1},
#  {'name': 'New Caledonia',
#   'main': False,
#   'geometry': 0    (POLYGON ((168.137461785 -21.43181731599993, 1...
#   dtype: object,
#   'rowroot': 2,
#   'colroot': 0,
#   'rowspan': 1,
#   'colspan': 1},
#  {'name': 'Reunion Island',
#   'main': False,
#   'geometry': 0    POLYGON ((55.78785241000008 -21.10344817499993...
#   dtype: object,
#   'rowroot': 1,
#   'colroot': 0,
#   'rowspan': 1,
#   'colspan': 1}]

# %%
lats = [33.658982] 
lons = [-111.925661]
crs = 4326
locations = gpd.GeoSeries(gpd.points_from_xy(lons, lats), crs=crs)

# %%
country_part = country_dict["parts"][0]

# %%
country_part
# Out:
# {'name': 'United States',
#  'main': True,
#  'geometry': 0    (POLYGON ((293.0989689460001 44.889390367, 293...
#  dtype: object,
#  'rowroot': 0,
#  'colroot': 2,
#  'rowspan': 4,
#  'colspan': 3}

# %%
is_location_in_country_part = locations.intersects(country_part["geometry"].iloc[0])

# %%
-111.925661+360
# Out:
# 248.074339

# %%
is_location_in_country_part
# Out:
# 0    False
# dtype: bool

# %%
str(country_part["geometry"].iloc[0])
# Out:
# 'MULTIPOLYGON (((293.0989689460001 44.889390367, 293.0833439460001 44.87767161700003, 293.0690210300001 44.86985911700002, 293.0794376960001 44.85032786700002, 293.0807397800001 44.83730703300006, 293.0612085300001 44.83860911700004, 293.0442814460001 44.84642161700003, 293.0247501960001 44.86074453300005, 293.0182397800001 44.87246328300004, 293.0416772800001 44.87767161700003, 293.0455835300001 44.889390367, 293.0455835300001 44.89980703300006, 293.0533960300001 44.91543203300007, 293.0599064460001 44.92584870000005, 293.0664168630001 44.94147370000008, 293.0781356130001 44.94798411700003, 293.0950626960001 44.95579661700005, 293.0950626960001 44.94668203300007, 293.0963647800001 44.93366120000007, 293.1080835300001 44.92194245000007, 293.1067814460001 44.90631745000007, 293.0989689460001 44.889390367)), ((293.0364689460001 44.96100495000008, 293.0221460300001 44.93626536700002, 293.0143335300001 44.92584870000005, 292.9948022800001 44.94798411700003, 292.9856876960001 44.96360911700003, 292.9830835300001 44.97923411700004, 292.9948022800001 44.98965078300005, 293.0104272800001 45.00136953300004, 293.0260522800001 45.01829661700003, 293.0455835300001 45.02741120000006, 293.0612085300001 45.02480703300005, 293.0599064460001 45.01178620000009, 293.0546981130001 45.00006745000007, 293.0520939460001 44.98314036700003, 293.0364689460001 44.96100495000008)), ((264.8394307860001 49.36949412100009, 264.8971791990001 49.35393951500008, 265.0174819330001 49.35616160100007, 265.0739125970001 49.345567933, 265.1438049710001 49.31828277600008, 265.1608581950001 49.30887766500003, 265.1727437740001 49.29285797199999, 265.180107665 49.25203359000008, 265.1896419670001 49.22960601900009, 265.1938794340001 49.21089915000004, 265.1888151440002 49.16656077100007, 265.1962565500002 49.14640696300008, 265.2079612630001 49.12645986000006, 265.2462276600002 49.02615590400001, 265.2887832030001 48.9145864870001, 265.2882664380001 48.86275502599999, 265.2878530270001 48.84244618700009, 265.2867161450001 48.82384267200005, 265.2890932610001 48.80751292000009, 265.2982141510001 48.79009796200007, 265.3111074210001 48.778832499, 265.4071480710001 48.72643259700009, 265.4808386630001 48.70447011300011, 265.5205003250001 48.70069773400009, 265.6884228920001 48.71392690000008, 265.7074139810001 48.71191152000004, 265.7159664300001 48.70906931600005, 265.7255007320001 48.70410837799999, 265.7345182700001 48.69775217699999, 265.7415462640001 48.69082753600011, 265.7442334390001 48.68354115800013, 265.7475407310001 48.66240549700007, 265.7489618320001 48.65728953000009, 265.7678495680001 48.65201853500007, 265.9651501870001 48.64331105600009, 266.1251145820002 48.63620554600006, 266.1642594800001 48.61713694300008, 266.190614461 48.54357554100007, 266.221336099 48.51946848600003, 266.2432210690001 48.51654876700004, 266.3837034500001 48.53130238900004, 266.4001107170001 48.52634145100003, 266.4334161780001 48.53827870700005, 266.5082436520001 48.54230946900004, 266.5400763340001 48.55739898700003, 266.5477502850001 48.57272105000002, 266.5462258290002 48.58695790700008, 266.5485254310001 48.59742238400013, 266.5826835530002 48.60411448200004, 266.6142836910001 48.61486318000005, 266.7422603750001 48.63031443300007, 266.8682991940001 48.62463002500004, 267.0202795820001 48.61767954600005, 267.0444124750001 48.61222768200003, 267.1158034670001 48.57987823500007, 267.2744501130001 48.5486915080001, 267.3513963210002 48.53626332600003, 267.3698189690001 48.51946848600003, 267.3725319810001 48.50277699800001, 267.3532566730001 48.49742848800008, 267.3086340740001 48.489857891, 267.2893587640002 48.48288157200001, 267.2810905350001 48.45978220700003, 267.295947509 48.44515777600004, 267.3228709310001 48.44174713200005, 267.342947224 48.43823313400006, 267.4294794110001 48.44665639300004, 267.4730684810001 48.44562286400007, 267.5093711750001 48.43311716800009, 267.5254683840001 48.41048289000003, 267.5324188630001 48.39428232900003, 267.532935628 48.35322540300009 ...

# %%
country_part["geometry"].iloc[0].buffer(distance=0.1)
